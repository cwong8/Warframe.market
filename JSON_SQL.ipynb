# %% [markdown]
# # Schema design
# We need to design a schema for our database.
#
# We are using the [Warframe.market API](https://docs.google.com/document/d/1121cjBNN4BeZdMBGil6Qbuqse-sWpEXPpitQH5fb_Fo/edit).

# %%
# MySQL create database - make sure your MySQL bin (...\MySQL\MySQL Server 8.0\bin) is in your %PATH% global environment
# Then run this in your command prompt: 
#    mysql -u user -p
#    CREATE DATABASE warframe_market;

# Server connection to MySQL:
import MySQLdb
conn = MySQLdb.connect(host= "localhost",
                  user="root",
                  passwd="4216UGOk!2013R@MS!",
                  db="warframe_market")

x = conn.cursor()

# %%
import requests
import numpy as np
import pandas as pd

# Start session
s = requests.Session()
s.headers.update({"Platform":"pc", "Language":"en"})

# Get all items JSON data from API
items = s.get("https://api.warframe.market/v1/items").json()
items
# Out:
# {'payload': {'items': {'en': [{'thumb': 'sub_icons/handle_128x128.png',
#      'item_name': 'Scindo Prime Handle',
#      'id': '54a73e65e779893a797fff5d',
#      'url_name': 'scindo_prime_handle'},
#     {'thumb': 'sub_icons/neuroptics_128x128.png',
#      'item_name': 'Ember Prime Neuroptics',
#      'id': '54a73e65e779893a797fff6d',
#      'url_name': 'ember_prime_neuroptics'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Loki Prime Blueprint',
#      'id': '54a73e65e779893a797fff7c',
#      'url_name': 'loki_prime_blueprint'},
#     {'thumb': 'sub_icons/chassis_128x128.png',
#      'item_name': 'Ember Prime Chassis',
#      'id': '54a73e65e779893a797fff7e',
#      'url_name': 'ember_prime_chassis'},
#     {'thumb': 'icons/en/thumbs/Hammer_Shot.fb11fe7457d821871f4c92b9acea585e.128x128.png',
#      'item_name': 'Hammer Shot',
#      'id': '54a74454e779892d5e51558d',
#      'url_name': 'hammer_shot'},
#     {'thumb': 'icons/en/thumbs/Seeking_Force.9efcc6f0d43c53ca9a57a65d753de6f3.128x128.png',
#      'item_name': 'Seeking Force',
#      'id': '54a74454e779892d5e51558f',
#      'url_name': 'seeking_force'},
#     {'thumb': 'icons/en/thumbs/Target_Cracker.6b81dd2b57724976438b9b083f8301f3.128x128.png',
#      'item_name': 'Target Cracker',
#      'id': '54a74454e779892d5e515595',
#      'url_name': 'target_cracker'},
#     {'thumb': 'icons/en/thumbs/Fleeting_Expertise.30c89f6ff728063e5579edd42dd7f811.128x128.png',
#      'item_name': 'Fleeting Expertise',
#      'id': '54a74454e779892d5e515598',
#      'url_name': 'fleeting_expertise'},
#     {'thumb': 'icons/en/thumbs/Critical_Delay.5e621ae9ee9a6d2d4576565a26af45cb.128x128.png',
#      'item_name': 'Critical Delay',
#      'id': '54a74454e779892d5e51559e',
#      'url_name': 'critical_delay'},
#     {'thumb': 'icons/en/thumbs/Ruinous_Extension.25e7e56624d0e1dbf1197ef7834a5e24.128x128.png',
#      'item_name': 'Ruinous Extension',
#      'id': '54a74454e779892d5e5155a1',
#      'url_name': 'ruinous_extension'},
#     {'thumb': 'icons/en/thumbs/Savagery.c02dd408812e29360368792883093dba.128x128.png',
#      'item_name': 'Savagery',
#      'id': '54a74454e779892d5e5155a2',
#      'url_name': 'savagery'},
#     {'thumb': 'icons/en/thumbs/Expel_Infested.7796f9a557ec4ad1336434c677df218f.128x128.png',
#      'item_name': 'Expel Infested',
#      'id': '54a74454e779892d5e5155a4',
#      'url_name': 'expel_infested'},
#     {'thumb': 'icons/en/thumbs/Warrior.f242df87020912815a276c2b9160c411.128x128.png',
#      'item_name': 'Warrior',
#      'id': '54a74454e779892d5e5155a7',
#      'url_name': 'warrior'},
#     {'thumb': 'icons/en/thumbs/Combustion_Rounds.5f8d4224dcdc992f9029cd491cd98f35.128x128.png',
#      'item_name': 'Combustion Rounds',
#      'id': '54a74454e779892d5e5155c7',
#      'url_name': 'combustion_rounds'},
#     {'thumb': 'icons/en/thumbs/Sniper_Ammo_Mutation.b1a91ddd13035a8130e10c35cd895faf.128x128.png',
#      'item_name': 'Sniper Ammo Mutation',
#      'id': '54a74454e779892d5e5155c9',
#      'url_name': 'sniper_ammo_mutation'},
#     {'thumb': 'icons/en/thumbs/Pistol_Gambit.b7912cda548f169c61b0102350caa3ad.128x128.png',
#      'item_name': 'Pistol Gambit',
#      'id': '54a74454e779892d5e5155ca',
#      'url_name': 'pistol_gambit'},
#     {'thumb': 'icons/en/thumbs/Blind_Rage.a3969916d438992c1b132d3c56ded7a5.128x128.png',
#      'item_name': 'Blind Rage',
#      'id': '54a74454e779892d5e5155cc',
#      'url_name': 'blind_rage'},
#     {'thumb': 'icons/en/thumbs/Rifle_Ammo_Mutation.ceb8ace4467da7e032915e6330d9cf65.128x128.png',
#      'item_name': 'Rifle Ammo Mutation',
#      'id': '54a74454e779892d5e5155d1',
#      'url_name': 'rifle_ammo_mutation'},
#     {'thumb': 'icons/en/thumbs/Magnum_Force.fe3fe64c3f25669b162ebe177544ffff.128x128.png',
#      'item_name': 'Magnum Force',
#      'id': '54a74454e779892d5e5155d3',
#      'url_name': 'magnum_force'},
#     {'thumb': 'icons/en/thumbs/Gleaming_Blight.864cbc195d8dbbdb4adfdadd56d7de13.128x128.png',
#      'item_name': 'Gleaming Blight',
#      'id': '54a74454e779892d5e5155d5',
#      'url_name': 'gleaming_blight'},
#     {'thumb': 'icons/en/thumbs/Vile_Precision.8b4bb8b7e4906de9e2c199af1a4407d5.128x128.png',
#      'item_name': 'Vile Precision',
#      'id': '54a74454e779892d5e5155f6',
#      'url_name': 'vile_precision'},
#     {'thumb': 'icons/en/thumbs/Parallax_Scope.733e5e6c2f4ae0dd23263865e11fafa5.128x128.png',
#      'item_name': 'Parallax Scope',
#      'id': '54a74454e779892d5e5155f8',
#      'url_name': 'parallax_scope'},
#     {'thumb': 'icons/en/thumbs/Vitality.dc0a453e7346e5dfe6e297413ee30740.128x128.png',
#      'item_name': 'Vitality',
#      'id': '54a74454e779892d5e5155fe',
#      'url_name': 'vitality'},
#     {'thumb': 'icons/en/thumbs/Sniper_Scavenger.fc4f17404bac3a608b6d5abb2990b66d.128x128.png',
#      'item_name': 'Sniper Scavenger',
#      'id': '54a74454e779892d5e515609',
#      'url_name': 'sniper_scavenger'},
#     {'thumb': 'icons/en/thumbs/Barrel_Diffusion.3c2fbabc91cc911e56dc43b046b9ecdb.128x128.png',
#      'item_name': 'Barrel Diffusion',
#      'id': '54a74454e779892d5e51560e',
#      'url_name': 'barrel_diffusion'},
#     {'thumb': 'icons/en/thumbs/Whirlwind.80aebc2d1fc7a32c71c31d57142b555b.128x128.png',
#      'item_name': 'Whirlwind',
#      'id': '54a74454e779892d5e51563a',
#      'url_name': 'whirlwind'},
#     {'thumb': 'icons/en/thumbs/Antitoxin.a03872dae3e9b75b7f278d6f9007816c.128x128.png',
#      'item_name': 'Antitoxin',
#      'id': '54a74454e779892d5e51563b',
#      'url_name': 'antitoxin'},
#     {'thumb': 'icons/en/thumbs/Disruptor.059fd9d2db6d766925cad2ca29234cb3.128x128.png',
#      'item_name': 'Disruptor',
#      'id': '54a74454e779892d5e51563c',
#      'url_name': 'disruptor'},
#     {'thumb': 'icons/en/thumbs/Heavy_Caliber.495eed0ad86012fe04049b94426c90ec.128x128.png',
#      'item_name': 'Heavy Caliber',
#      'id': '54a74454e779892d5e51563d',
#      'url_name': 'heavy_caliber'},
#     {'thumb': 'icons/en/thumbs/Piercing_Hit.f2c3f27b03f5a40d3e8a6b6f7d8cfafe.128x128.png',
#      'item_name': 'Piercing Hit',
#      'id': '54a74454e779892d5e51563e',
#      'url_name': 'piercing_hit'},
#     {'thumb': 'icons/en/thumbs/Continuity.c8f4628b5ad77db5bee66f587e6a1b96.128x128.png',
#      'item_name': 'Continuity',
#      'id': '54a74454e779892d5e515642',
#      'url_name': 'continuity'},
#     {'thumb': 'icons/en/thumbs/Tainted_Clip.bbcdd9d47cba552ded5731145f9998a3.128x128.png',
#      'item_name': 'Tainted Clip',
#      'id': '54a74454e779892d5e51564e',
#      'url_name': 'tainted_clip'},
#     {'thumb': 'icons/en/thumbs/Freeze_Force.76d7a06e084231ef174fdb02079b8389.128x128.png',
#      'item_name': 'Freeze Force',
#      'id': '54a74454e779892d5e515652',
#      'url_name': 'freeze_force'},
#     {'thumb': 'icons/en/thumbs/Swirling_Tiger.5431981727f51665abe320cce8fc84b4.128x128.png',
#      'item_name': 'Swirling Tiger',
#      'id': '54a74454e779892d5e515656',
#      'url_name': 'swirling_tiger'},
#     {'thumb': 'icons/en/thumbs/Shock_Trooper.49895e046fdca37d2f6308e528165f82.128x128.png',
#      'item_name': 'Shock Trooper',
#      'id': '54a74454e779892d5e515658',
#      'url_name': 'shock_trooper'},
#     {'thumb': 'icons/en/thumbs/Quick_Thinking.062fbe5be0dfb26fa2f268b338cae078.128x128.png',
#      'item_name': 'Quick Thinking',
#      'id': '54a74455e779892d5e51568d',
#      'url_name': 'quick_thinking'},
#     {'thumb': 'icons/en/thumbs/Flow.f8307937a89740f0650d730c3d59da3f.128x128.png',
#      'item_name': 'Flow',
#      'id': '54a74455e779892d5e51568e',
#      'url_name': 'flow'},
#     {'thumb': 'icons/en/thumbs/Blazing_Steel.4462c08189e7218a64537da221faa4c6.128x128.png',
#      'item_name': 'Blazing Steel',
#      'id': '54a74455e779892d5e515692',
#      'url_name': 'blazing_steel'},
#     {'thumb': 'icons/en/thumbs/Critical_Deceleration.1e6f0389e96ef70a93f09667ac7282a4.128x128.png',
#      'item_name': 'Critical Deceleration',
#      'id': '54a74455e779892d5e515698',
#      'url_name': 'critical_deceleration'},
#     {'thumb': 'icons/en/thumbs/Fired_Up.33e41b63a3f193f1e801b503a1afb585.128x128.png',
#      'item_name': 'Fired Up',
#      'id': '54a74455e779892d5e51569b',
#      'url_name': 'fired_up'},
#     {'thumb': 'icons/en/thumbs/Expel_Corpus.a5014be781ec3ac619fd3d7260e8fa36.128x128.png',
#      'item_name': 'Expel Corpus',
#      'id': '54a74455e779892d5e51569f',
#      'url_name': 'expel_corpus'},
#     {'thumb': 'icons/en/thumbs/Shattering_Storm.db1b1e72c57367903c6c7baad6461aa6.128x128.png',
#      'item_name': 'Shattering Storm',
#      'id': '54a74455e779892d5e5156ac',
#      'url_name': 'shattering_storm'},
#     {'thumb': 'icons/en/thumbs/Lingering_Torment.e63fea80ff3cb599d0840090716ad730.128x128.png',
#      'item_name': 'Lingering Torment',
#      'id': '54a74455e779892d5e5156ad',
#      'url_name': 'lingering_torment'},
#     {'thumb': 'icons/en/thumbs/Provoked.d03668dd7faa355653d8c8b691520299.128x128.png',
#      'item_name': 'Provoked',
#      'id': '54a74455e779892d5e5156b4',
#      'url_name': 'provoked'},
#     {'thumb': 'icons/en/thumbs/Spoiled_Strike.79611a3d5edd3c4cfaa9a6c514cc6310.128x128.png',
#      'item_name': 'Spoiled Strike',
#      'id': '54a74455e779892d5e5156b6',
#      'url_name': 'spoiled_strike'},
#     {'thumb': 'icons/en/thumbs/Incendiary_Coat.08c60b348153dcf1a33305345e93cc79.128x128.png',
#      'item_name': 'Incendiary Coat',
#      'id': '54a74455e779892d5e5156bc',
#      'url_name': 'incendiary_coat'},
#     {'thumb': 'icons/en/thumbs/Split_Chamber.2cb0a97bd2c5e9d75a505a153e8230cc.128x128.png',
#      'item_name': 'Split Chamber',
#      'id': '54a74455e779892d5e5156be',
#      'url_name': 'split_chamber'},
#     {'thumb': 'icons/en/thumbs/Safeguard_Switch.0d84e8aee50d18ced179eddf30cdc991.128x128.png',
#      'item_name': 'Safeguard Switch',
#      'id': '54a74455e779892d5e5156c3',
#      'url_name': 'safeguard_switch'},
#     {'thumb': 'icons/en/thumbs/Enemy_Radar.cee8b527e0265bb39d41e9aa541ac781.128x128.png',
#      'item_name': 'Enemy Radar',
#      'id': '54a74455e779892d5e5156c6',
#      'url_name': 'enemy_radar'},
#     {'thumb': 'icons/en/thumbs/Heated_Charge.49a85d4cb5d62cd1e7828ad7f418a61c.128x128.png',
#      'item_name': 'Heated Charge',
#      'id': '54a74455e779892d5e5156c7',
#      'url_name': 'heated_charge'},
#     {'thumb': 'icons/en/thumbs/Hellfire.6b16f100ae3536c790154ad38b575e6d.128x128.png',
#      'item_name': 'Hellfire',
#      'id': '54a74455e779892d5e5156c9',
#      'url_name': 'hellfire'},
#     {'thumb': 'icons/en/thumbs/Eagle_Eye.84b925bc0a194c323f0a54f5ea4a2cd5.128x128.png',
#      'item_name': 'Eagle Eye',
#      'id': '54a74455e779892d5e5156cc',
#      'url_name': 'eagle_eye'},
#     {'thumb': 'icons/en/thumbs/Argon_Plating.fa183b27e0d58aba993369ad910ab455.128x128.png',
#      'item_name': 'Argon Plating',
#      'id': '54a74455e779892d5e5156cd',
#      'url_name': 'argon_plating'},
#     {'thumb': 'icons/en/thumbs/System_Reroute.6a07c1195da733426a0512cbf7d17264.128x128.png',
#      'item_name': 'System Reroute',
#      'id': '54a74455e779892d5e5156cf',
#      'url_name': 'system_reroute'},
#     {'thumb': 'icons/en/thumbs/North_Wind.ddcfeab6866eb1c752ab79e55f001abb.128x128.png',
#      'item_name': 'North Wind',
#      'id': '54a74455e779892d5e5156d1',
#      'url_name': 'north_wind'},
#     {'thumb': 'icons/en/thumbs/Shotgun_Scavenger.1f23255c80dbcc3c34e4505c9479f931.128x128.png',
#      'item_name': 'Shotgun Scavenger',
#      'id': '54a74455e779892d5e5156d3',
#      'url_name': 'shotgun_scavenger'},
#     {'thumb': 'icons/en/thumbs/Synoid_Gammacor.16811422b2fab432718fd630acbf5358.128x128.png',
#      'item_name': 'Synoid Gammacor',
#      'id': '54aae283e779897f276a5768',
#      'url_name': 'synoid_gammacor'},
#     {'thumb': 'icons/en/thumbs/Rakta_Ballistica.2e338918b2298e17fa465e83d319cc13.128x128.png',
#      'item_name': 'Rakta Ballistica',
#      'id': '54aae2a0e7798911533cb007',
#      'url_name': 'rakta_ballistica'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Wyrm Prime Blueprint',
#      'id': '54ca431ce779891a1adb4901',
#      'url_name': 'wyrm_prime_blueprint'},
#     {'thumb': 'sub_icons/carapace_128x128.png',
#      'item_name': 'Wyrm Prime Carapace',
#      'id': '54ca4330e779891a286a5428',
#      'url_name': 'wyrm_prime_carapace'},
#     {'thumb': 'icons/en/thumbs/Fire_Fright.7cd71a53543fdc9c251338c76a3216b6.128x128.png',
#      'item_name': 'Fire Fright',
#      'id': '54e0c9eee7798903744178ae',
#      'url_name': 'fire_fright'},
#     {'thumb': 'icons/en/thumbs/Shield_Overload.e2751dfa85b7b91e170d549cd1f6b574.128x128.png',
#      'item_name': 'Shield Overload',
#      'id': '554d3c0ce7798942793d7e8a',
#      'url_name': 'shield_overload'},
#     {'thumb': 'icons/en/thumbs/Atlantis_Vulcan.e996f3c43cc79c72236bd8b5b422fc65.128x128.png',
#      'item_name': 'Atlantis Vulcan',
#      'id': '56153836b66f836fa7d42c8c',
#      'url_name': 'atlantis_vulcan'},
#     {'thumb': 'icons/en/thumbs/Arcane_Pulse.9f9a959b60addb3377fec907f8c5d35b.128x128.png',
#      'item_name': 'Arcane Pulse',
#      'id': '56153e9bb66f837074af99c5',
#      'url_name': 'arcane_pulse'},
#     {'thumb': 'icons/en/thumbs/Prisma_Tetra.e1e516760ccd856f2a66a1992d7e98e1.128x128.png',
#      'item_name': 'Prisma Tetra',
#      'id': '56153f21b66f83707a67c0b4',
#      'url_name': 'prisma_tetra'},
#     {'thumb': 'icons/en/thumbs/Calculated_Shot.083e6571a4d27ca0ba592ce5bc617f69.128x128.png',
#      'item_name': 'Calculated Shot',
#      'id': '5615432bb66f8371035bfa23',
#      'url_name': 'calculated_shot'},
#     {'thumb': 'icons/en/thumbs/Arc_Coil.0df8ece91fb4defa7ce30c1990cbe862.128x128.png',
#      'item_name': 'Arc Coil',
#      'id': '5615432bb66f8371035bfa25',
#      'url_name': 'arc_coil'},
#     {'thumb': 'icons/en/thumbs/Chaos_Sphere.4194f4d65e462bfc107592b025aef339.128x128.png',
#      'item_name': 'Chaos Sphere',
#      'id': '5615432bb66f8371035bfa26',
#      'url_name': 'chaos_sphere'},
#     {'thumb': 'icons/en/thumbs/Hysterical_Fixation.ee66a28ce6af173f246b554544b1121f.128x128.png',
#      'item_name': 'Hysterical Fixation',
#      'id': '5615432bb66f8371035bfa27',
#      'url_name': 'hysterical_fixation'},
#     {'thumb': 'icons/en/thumbs/Sonic_Fracture.42750ffc5b0a98753ad727b73c1ef3d6.128x128.png',
#      'item_name': 'Sonic Fracture',
#      'id': '5615432bb66f8371035bfa2a',
#      'url_name': 'sonic_fracture'},
#     {'thumb': 'icons/en/thumbs/Defiled_Reckoning.a2814ddc291d021dc6e3ea9d9c88e92b.128x128.png',
#      'item_name': 'Defiled Reckoning',
#      'id': '5615432bb66f8371035bfa2b',
#      'url_name': 'defiled_reckoning'},
#     {'thumb': 'icons/en/thumbs/Hikou_Prime_Set.cd5cefce60a4e85c15614139a8ee9400.128x128.png',
#      'item_name': 'Hikou Prime Set',
#      'id': '56783f24cbfa8f0432dd899e',
#      'url_name': 'hikou_prime_set'},
#     {'thumb': 'icons/en/thumbs/Paris_Prime_Set.971f957f8304ce10617836343d47b238.128x128.png',
#      'item_name': 'Paris Prime Set',
#      'id': '56783f24cbfa8f0432dd89a9',
#      'url_name': 'paris_prime_set'},
#     {'thumb': 'icons/en/thumbs/Trinity_Prime_Set.4115dba418ab8ee70197a7fdaee8da76.128x128.png',
#      'item_name': 'Trinity Prime Set',
#      'id': '56783f24cbfa8f0432dd89af',
#      'url_name': 'trinity_prime_set'},
#     {'thumb': 'icons/en/thumbs/Vasto_Prime_Set.213e4b3b9b3be0f4facb77fd5242b6a4.128x128.png',
#      'item_name': 'Vasto Prime Set',
#      'id': '56783f24cbfa8f0432dd89b0',
#      'url_name': 'vasto_prime_set'},
#     {'thumb': 'icons/en/thumbs/Rift_Strike.37fa7334f532fe72ffd8c452c7791387.128x128.png',
#      'item_name': 'Rift Strike',
#      'id': '5729bd11cb59ed5a9b484e90',
#      'url_name': 'rift_strike'},
#     {'thumb': 'icons/en/thumbs/Vulcan_Blitz.c41b4bfac727e7cea0856441c3d4df7b.128x128.png',
#      'item_name': 'Vulcan Blitz',
#      'id': '5729bd15cb59ed5a9b484e91',
#      'url_name': 'vulcan_blitz'},
#     {'thumb': 'icons/en/thumbs/Fomorian_Accelerant.703cc26fdc88d12f834c157eae51704e.128x128.png',
#      'item_name': 'Fomorian Accelerant',
#      'id': '5729bd18cb59ed5a9b484e92',
#      'url_name': 'fomorian_accelerant'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Imperator Vandal Blueprint',
#      'id': '5740c1679d238d4a03d28514',
#      'url_name': 'imperator_vandal_blueprint'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Imperator Vandal Barrel',
#      'id': '5740c16d9d238d4a03d28515',
#      'url_name': 'imperator_vandal_barrel'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Velocitus Stock',
#      'id': '5783bf10d9b6753790c89e8a',
#      'url_name': 'velocitus_stock'},
#     {'thumb': 'icons/en/thumbs/Lith_F1_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith F1 Exceptional',
#      'id': '5788f4b44fff472f131a12f0',
#      'url_name': 'lith_f1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_V1_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V1 Exceptional',
#      'id': '5788f5df4fff472f131a1338',
#      'url_name': 'neo_v1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Axi_S1_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi S1 Flawless',
#      'id': '5788f6224fff472f131a1351',
#      'url_name': 'axi_s1_flawless'},
#     {'thumb': 'sub_icons/handle_128x128.png',
#      'item_name': 'Rathbone Handle',
#      'id': '578d33bf34003bbbb9e20924',
#      'url_name': 'rathbone_handle'},
#     {'thumb': 'sub_icons/generic_head_128x128.png',
#      'item_name': 'Rathbone Head',
#      'id': '578d33bf34003bbbb9e20925',
#      'url_name': 'rathbone_head'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Latron Wraith Barrel',
#      'id': '57962daf19aaba0b00a9b1b0',
#      'url_name': 'latron_wraith_barrel'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Latron Wraith Blueprint',
#      'id': '57962daf19aaba0b00a9b1b1',
#      'url_name': 'latron_wraith_blueprint'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Latron Wraith Receiver',
#      'id': '57962daf19aaba0b00a9b1b2',
#      'url_name': 'latron_wraith_receiver'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Latron Wraith Stock',
#      'id': '57962daf19aaba0b00a9b1b3',
#      'url_name': 'latron_wraith_stock'},
#     {'thumb': 'icons/en/thumbs/Latron_Wraith_Set.57295b3f36571ea8ea47471d7a70caea.128x128.png',
#      'item_name': 'Latron Wraith Set',
#      'id': '57962daf19aaba0b00a9b1b4',
#      'url_name': 'latron_wraith_set'},
#     {'thumb': 'icons/en/thumbs/Territorial_Aggression.fe5b1085fb610c35d7318fb07524b81c.128x128.png',
#      'item_name': 'Territorial Aggression',
#      'id': '57b4e5486f6b2fda8ea6caa0',
#      'url_name': 'territorial_aggression'},
#     {'thumb': 'icons/en/thumbs/Swipe.9cd13bf445a46803ff0439d6333f49d9.128x128.png',
#      'item_name': 'Swipe',
#      'id': '57b4e5486f6b2fda8ea6caa1',
#      'url_name': 'swipe'},
#     {'thumb': 'icons/en/thumbs/Pounce.3ab83e349347ec39631b9f203e5ec42c.128x128.png',
#      'item_name': 'Pounce',
#      'id': '57b4e5486f6b2fda8ea6caa2',
#      'url_name': 'pounce'},
#     {'thumb': 'icons/en/thumbs/Sharpened_Claws.52d84f002b93e89569ee95d885e585c9.128x128.png',
#      'item_name': 'Sharpened Claws',
#      'id': '57b4e5486f6b2fda8ea6caa3',
#      'url_name': 'sharpened_claws'},
#     {'thumb': 'icons/en/thumbs/Sense_Danger.03bc6b34f166a4aa51c6e69fe8bf4348.128x128.png',
#      'item_name': 'Sense Danger',
#      'id': '57b4e5486f6b2fda8ea6caa4',
#      'url_name': 'sense_danger'},
#     {'thumb': 'icons/en/thumbs/Bullet_Dance.fe9f7dce282e60438ffc589647890577.128x128.png',
#      'item_name': 'Bullet Dance',
#      'id': '57b86950315399578ef1a6bd',
#      'url_name': 'bullet_dance'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Twin Vipers Wraith Blueprint',
#      'id': '57bc948ae506eb45ea25144c',
#      'url_name': 'twin_vipers_wraith_blueprint'},
#     {'thumb': 'sub_icons/link_128x128.png',
#      'item_name': 'Twin Vipers Wraith Link',
#      'id': '57bc948ae506eb45ea25144e',
#      'url_name': 'twin_vipers_wraith_link'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Twin Vipers Wraith Receivers',
#      'id': '57bc948ae506eb45ea25144f',
#      'url_name': 'twin_vipers_wraith_receivers'},
#     {'thumb': 'icons/en/thumbs/Twin_Vipers_Wraith_Set.c80af69695edc4c30fb44018404ea432.128x128.png',
#      'item_name': 'Twin Vipers Wraith Set',
#      'id': '57bc94bae506eb45ea251450',
#      'url_name': 'twin_vipers_wraith_set'},
#     {'thumb': 'sub_icons/chassis_128x128.png',
#      'item_name': 'Nekros Prime Chassis',
#      'id': '57bc9a40e506eb45ea251452',
#      'url_name': 'nekros_prime_chassis'},
#     {'thumb': 'sub_icons/neuroptics_128x128.png',
#      'item_name': 'Nekros Prime Neuroptics',
#      'id': '57bc9a40e506eb45ea251453',
#      'url_name': 'nekros_prime_neuroptics'},
#     {'thumb': 'icons/en/thumbs/Lith_G1_Radiant.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith G1 Radiant',
#      'id': '5848092a2c2ada00798f3362',
#      'url_name': 'lith_g1_radiant'},
#     {'thumb': 'icons/en/thumbs/Draining_Gloom.4d6890c07e01806ae034fd391d0a721c.128x128.png',
#      'item_name': 'Draining Gloom',
#      'id': '585a925a2c2ada004285df01',
#      'url_name': 'draining_gloom'},
#     {'thumb': 'icons/en/thumbs/Precision_Munition.475b011473c1252788f6d63a43dfa651.128x128.png',
#      'item_name': 'Precision Munition',
#      'id': '585a93312c2ada00552edf0f',
#      'url_name': 'precision_munition'},
#     {'thumb': 'icons/en/thumbs/Neo_S6_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo S6 Flawless',
#      'id': '5936de2a16efa3a742b15f59',
#      'url_name': 'neo_s6_flawless'},
#     {'thumb': 'icons/en/thumbs/Lith_N2_Flawless.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith N2 Flawless',
#      'id': '58d8f31c11efe42a5e523216',
#      'url_name': 'lith_n2_flawless'},
#     {'thumb': 'icons/en/thumbs/Axi_R1_Intact.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi R1 Intact',
#      'id': '595be1218e34b5ed3cb3d9cc',
#      'url_name': 'axi_r1_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_B1_Intact.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith B1 Intact',
#      'id': '595be1218e34b5ed3cb3d9c0',
#      'url_name': 'lith_b1_intact'},
#     {'thumb': 'icons/en/thumbs/Meso_F1_Intact.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso F1 Intact',
#      'id': '58dbcc9570b42255d6321e8a',
#      'url_name': 'meso_f1_intact'},
#     {'thumb': 'icons/en/thumbs/Axi_E2_Intact.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi E2 Intact',
#      'id': '58d8f33b11efe42a5e523224',
#      'url_name': 'axi_e2_intact'},
#     {'thumb': 'icons/en/thumbs/Neo_V2_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V2 Exceptional',
#      'id': '5824d0688087398a4415b31e',
#      'url_name': 'neo_v2_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_S6_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith S6 Exceptional',
#      'id': '59820289094e272376d812be',
#      'url_name': 'lith_s6_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_S3_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith S3 Exceptional',
#      'id': '59820289094e272376d812b2',
#      'url_name': 'lith_s3_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_V3_Radiant.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith V3 Radiant',
#      'id': '58d8f32b11efe42a5e52321f',
#      'url_name': 'lith_v3_radiant'},
#     {'thumb': 'icons/en/thumbs/Lith_K1_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith K1 Exceptional',
#      'id': '58e2345aea9f4c51081fed72',
#      'url_name': 'lith_k1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_V4_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V4 Flawless',
#      'id': '5835a4404b0377e226bdc35a',
#      'url_name': 'neo_v4_flawless'},
#     {'thumb': 'icons/en/thumbs/Meso_S5_Exceptional.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso S5 Exceptional',
#      'id': '5936dd9916efa3a742b15f4c',
#      'url_name': 'meso_s5_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_B1_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo B1 Exceptional',
#      'id': '58d8f2fb11efe42a5e523205',
#      'url_name': 'neo_b1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_V3_Flawless.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith V3 Flawless',
#      'id': '58d8f32b11efe42a5e52321e',
#      'url_name': 'lith_v3_flawless'},
#     {'thumb': 'icons/en/thumbs/Meso_M1_Exceptional.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso M1 Exceptional',
#      'id': '595be1218e34b5ed3cb3d9c5',
#      'url_name': 'meso_m1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_N5_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N5 Intact',
#      'id': '58d8f32511efe42a5e523218',
#      'url_name': 'neo_n5_intact'},
#     {'thumb': 'icons/en/thumbs/Axi_H1_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi H1 Flawless',
#      'id': '58d8f31411efe42a5e523212',
#      'url_name': 'axi_h1_flawless'},
#     {'thumb': 'icons/en/thumbs/Meso_F1_Exceptional.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso F1 Exceptional',
#      'id': '58dbcc9570b42255d6321e8b',
#      'url_name': 'meso_f1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_B3_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo B3 Intact',
#      'id': '595be1218e34b5ed3cb3d9c8',
#      'url_name': 'neo_b3_intact'},
#     {'thumb': 'icons/en/thumbs/Neo_A1_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo A1 Intact',
#      'id': '5835a4664b0377e226bdc368',
#      'url_name': 'neo_a1_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_N1_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith N1 Exceptional',
#      'id': '594274fd094397940dc9fb8e',
#      'url_name': 'lith_n1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Meso_N4_Radiant.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso N4 Radiant',
#      'id': '5936dcea16efa3a742b15f42',
#      'url_name': 'meso_n4_radiant'},
#     {'thumb': 'icons/en/thumbs/Lith_N2_Radiant.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith N2 Radiant',
#      'id': '58d8f31c11efe42a5e523217',
#      'url_name': 'lith_n2_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_H1_Exceptional.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi H1 Exceptional',
#      'id': '58d8f31411efe42a5e523211',
#      'url_name': 'axi_h1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_T1_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo T1 Exceptional',
#      'id': '58d8f30d11efe42a5e52320d',
#      'url_name': 'neo_t1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_S6_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo S6 Exceptional',
#      'id': '5936de2a16efa3a742b15f58',
#      'url_name': 'neo_s6_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_V5_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V5 Flawless',
#      'id': '5936de1416efa3a742b15f55',
#      'url_name': 'neo_v5_flawless'},
#     {'thumb': 'icons/en/thumbs/Axi_E2_Radiant.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi E2 Radiant',
#      'id': '58d8f33b11efe42a5e523227',
#      'url_name': 'axi_e2_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_O1_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi O1 Flawless',
#      'id': '5936db2616efa3a742b15f35',
#      'url_name': 'axi_o1_flawless'},
#     {'thumb': 'icons/en/thumbs/Neo_S5_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo S5 Intact',
#      'id': '584802ec15f1a99e894d9bd1',
#      'url_name': 'neo_s5_intact'},
#     {'thumb': 'icons/en/thumbs/Neo_N6_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N6 Flawless',
#      'id': '5936dde816efa3a742b15f51',
#      'url_name': 'neo_n6_flawless'},
#     {'thumb': 'icons/en/thumbs/Lith_C1_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith C1 Exceptional',
#      'id': '598b06b4ab6b61be6fec0faf',
#      'url_name': 'lith_c1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_V3_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith V3 Exceptional',
#      'id': '58d8f32b11efe42a5e52321d',
#      'url_name': 'lith_v3_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_N6_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N6 Exceptional',
#      'id': '5936dde816efa3a742b15f50',
#      'url_name': 'neo_n6_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_N5_Radiant.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N5 Radiant',
#      'id': '58d8f32511efe42a5e52321b',
#      'url_name': 'neo_n5_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_B1_Radiant.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi B1 Radiant',
#      'id': '58d8f2f311efe42a5e523203',
#      'url_name': 'axi_b1_radiant'},
#     {'thumb': 'icons/en/thumbs/Neo_V5_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V5 Intact',
#      'id': '5936de1416efa3a742b15f53',
#      'url_name': 'neo_v5_intact'},
#     {'thumb': 'icons/en/thumbs/Axi_A2_Radiant.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi A2 Radiant',
#      'id': '588c7c44c353473a172364f8',
#      'url_name': 'axi_a2_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_H2_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi H2 Flawless',
#      'id': '5936db1f16efa3a742b15f31',
#      'url_name': 'axi_h2_flawless'},
#     {'thumb': 'icons/en/thumbs/Neo_A1_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo A1 Flawless',
#      'id': '5835a4664b0377e226bdc36a',
#      'url_name': 'neo_a1_flawless'},
#     {'thumb': 'icons/en/thumbs/Neo_V2_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V2 Flawless',
#      'id': '5824d0688087398a4415b31f',
#      'url_name': 'neo_v2_flawless'},
#     {'thumb': 'icons/en/thumbs/Meso_S4_Radiant.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso S4 Radiant',
#      'id': '58d8f30411efe42a5e52320b',
#      'url_name': 'meso_s4_radiant'},
#     {'thumb': 'icons/en/thumbs/Neo_V3_Flawless.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo V3 Flawless',
#      'id': '5824d0688087398a4415b323',
#      'url_name': 'neo_v3_flawless'},
#     {'thumb': 'icons/en/thumbs/Axi_V4_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi V4 Flawless',
#      'id': '5835a4ae4b0377e226bdc372',
#      'url_name': 'axi_v4_flawless'},
#     {'thumb': 'icons/en/thumbs/Axi_A2_Intact.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi A2 Intact',
#      'id': '588c7c44c353473a172364f5',
#      'url_name': 'axi_a2_intact'},
#     {'thumb': 'icons/en/thumbs/Meso_O1_Exceptional.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso O1 Exceptional',
#      'id': '5936dd1816efa3a742b15f44',
#      'url_name': 'meso_o1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Meso_N5_Intact.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso N5 Intact',
#      'id': '59a5ce985cd9938cfede7047',
#      'url_name': 'meso_n5_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_V4_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith V4 Exceptional',
#      'id': '59eb9b3b52f90ed715e14152',
#      'url_name': 'lith_v4_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_B2_Exceptional.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith B2 Exceptional',
#      'id': '59a5cfa65cd9938cfede7064',
#      'url_name': 'lith_b2_exceptional'},
#     {'thumb': 'icons/en/thumbs/Meso_C3_Radiant.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso C3 Radiant',
#      'id': '59a5cf1d5cd9938cfede7056',
#      'url_name': 'meso_c3_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_V6_Radiant.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi V6 Radiant',
#      'id': '59a5cfe65cd9938cfede706e',
#      'url_name': 'axi_v6_radiant'},
#     {'thumb': 'icons/en/thumbs/Meso_S2_Radiant.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso S2 Radiant',
#      'id': '59eb9b2052f90ed715e14148',
#      'url_name': 'meso_s2_radiant'},
#     {'thumb': 'icons/en/thumbs/Axi_N5_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi N5 Flawless',
#      'id': '59a5cf1d5cd9938cfede7059',
#      'url_name': 'axi_n5_flawless'},
#     {'thumb': 'icons/en/thumbs/Neo_N7_Radiant.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N7 Radiant',
#      'id': '59eb9b3352f90ed715e14150',
#      'url_name': 'neo_n7_radiant'},
#     {'thumb': 'icons/en/thumbs/Neo_H1_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo H1 Exceptional',
#      'id': '59a5cf5f5cd9938cfede7060',
#      'url_name': 'neo_h1_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_S7_Exceptional.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo S7 Exceptional',
#      'id': '59a5d0325cd9938cfede7074',
#      'url_name': 'neo_s7_exceptional'},
#     {'thumb': 'icons/en/thumbs/Lith_T1_Flawless.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith T1 Flawless',
#      'id': '59a5cfc05cd9938cfede7069',
#      'url_name': 'lith_t1_flawless'},
#     {'thumb': 'icons/en/thumbs/Meso_S2_Flawless.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso S2 Flawless',
#      'id': '59eb9b2052f90ed715e14147',
#      'url_name': 'meso_s2_flawless'},
#     {'thumb': 'icons/en/thumbs/Lith_H1_Intact.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith H1 Intact',
#      'id': '59a5cf1d5cd9938cfede705b',
#      'url_name': 'lith_h1_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_B2_Intact.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith B2 Intact',
#      'id': '59a5cfa65cd9938cfede7063',
#      'url_name': 'lith_b2_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_T1_Radiant.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith T1 Radiant',
#      'id': '59a5cfc05cd9938cfede706a',
#      'url_name': 'lith_t1_radiant'},
#     {'thumb': 'icons/en/thumbs/Meso_N5_Exceptional.caee59471a7b06ca040f2d257083e008.128x128.png',
#      'item_name': 'Meso N5 Exceptional',
#      'id': '59a5ce985cd9938cfede7048',
#      'url_name': 'meso_n5_exceptional'},
#     {'thumb': 'icons/en/thumbs/Neo_N7_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo N7 Intact',
#      'id': '59eb9b3352f90ed715e1414d',
#      'url_name': 'neo_n7_intact'},
#     {'thumb': 'icons/en/thumbs/Lith_B2_Flawless.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith B2 Flawless',
#      'id': '59a5cfa65cd9938cfede7065',
#      'url_name': 'lith_b2_flawless'},
#     {'thumb': 'icons/en/thumbs/Lith_V4_Radiant.b82a140ba17908be7226fddcecd7bf62.128x128.png',
#      'item_name': 'Lith V4 Radiant',
#      'id': '59eb9b3b52f90ed715e14154',
#      'url_name': 'lith_v4_radiant'},
#     {'thumb': 'icons/en/thumbs/Neo_H1_Radiant.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo H1 Radiant',
#      'id': '59a5cf5f5cd9938cfede7062',
#      'url_name': 'neo_h1_radiant'},
#     {'thumb': 'icons/en/thumbs/Neo_S8_Intact.e0e38afae723757487927845b35a81d2.128x128.png',
#      'item_name': 'Neo S8 Intact',
#      'id': '59a5ce985cd9938cfede704f',
#      'url_name': 'neo_s8_intact'},
#     {'thumb': 'icons/en/thumbs/Axi_V6_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi V6 Flawless',
#      'id': '59a5cfe65cd9938cfede706d',
#      'url_name': 'axi_v6_flawless'},
#     {'thumb': 'icons/en/thumbs/Axi_N4_Flawless.99413ebefc5b87d57d9e5314265b56de.128x128.png',
#      'item_name': 'Axi N4 Flawless',
#      'id': '59a5ce985cd9938cfede704d',
#      'url_name': 'axi_n4_flawless'},
#     {'thumb': 'icons/en/thumbs/Disarming_Purity.051b3489272e846e1ea5ecc351ea9c32.128x128.png',
#      'item_name': 'Disarming Purity',
#      'id': '5911f11d97a0add8e9d5da4c',
#      'url_name': 'disarming_purity'},
#     {'thumb': 'icons/en/thumbs/Small_Yogwun.e19efadfd40b4a48e0dd46529706ddce.128x128.png',
#      'item_name': 'Small Yogwun',
#      'id': '59e6420c40c3ee1a65541c4f',
#      'url_name': 'small_yogwun'},
#     {'thumb': 'icons/en/thumbs/Helios_Prime_Set.625b7c74ea5dd61b1840f8094df7648a.128x128.png',
#      'item_name': 'Helios Prime Set',
#      'id': '58b57068eb26db5c31192114',
#      'url_name': 'helios_prime_set'},
#     {'thumb': 'sub_icons/generic_receiver_128x128.png',
#      'item_name': 'Gorgon Wraith Receiver',
#      'id': '591844575c170664fbd37eb5',
#      'url_name': 'gorgon_wraith_receiver'},
#     {'thumb': 'sub_icons/neuroptics_128x128.png',
#      'item_name': 'Hydroid Prime Neuroptics',
#      'id': '59a48b625cd9938cfede7039',
#      'url_name': 'hydroid_prime_neuroptics'},
#     {'thumb': 'icons/en/thumbs/Corpus_Void_Key.18020d99fc32c7d6e54733e1ebf4c7aa.128x128.png',
#      'item_name': 'Corpus Void Key',
#      'id': '56463b04b66f83585da94c6a',
#      'url_name': 'corpus_void_key'},
#     {'thumb': 'icons/en/thumbs/Chromatic_Blade.2d72fee7f3deddd7450241dca62bfd47.128x128.png',
#      'item_name': 'Chromatic Blade',
#      'id': '59385f6716efa3a742b15f60',
#      'url_name': 'chromatic_blade'},
#     {'thumb': 'sub_icons/neuroptics_128x128.png',
#      'item_name': 'Oberon Prime Neuroptics',
#      'id': '592dd262011e88f094afec7e',
#      'url_name': 'oberon_prime_neuroptics'},
#     {'thumb': 'icons/en/thumbs/Vigilante_Armaments.4aa8eaec104ba573159a2cbf207b6314.128x128.png',
#      'item_name': 'Vigilante Armaments',
#      'id': '59dfeb63115f1d887cfd7aba',
#      'url_name': 'vigilante_armaments'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Sybaris Prime Blueprint',
#      'id': '592dd262011e88f094afec82',
#      'url_name': 'sybaris_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Medium_Cuthol.534d729a30965fbad9471f4eb3e619c6.128x128.png',
#      'item_name': 'Medium Cuthol',
#      'id': '59e6421240c3ee1a65541c59',
#      'url_name': 'medium_cuthol'},
#     {'thumb': 'sub_icons/lower_limb_128x128.png',
#      'item_name': 'Ballistica Prime Lower Limb',
#      'id': '59a5cd4d5cd9938cfede7044',
#      'url_name': 'ballistica_prime_lower_limb'},
#     {'thumb': 'icons/en/thumbs/Marquise_Veridos.0ff6080823e396fc6d3d5946dc192d9b.128x128.png',
#      'item_name': 'Marquise Veridos',
#      'id': '59eba86952f90ed715e14157',
#      'url_name': 'marquise_veridos'},
#     {'thumb': 'icons/en/thumbs/Piercing_Navigator.ac1dd07d1c1ae58d59634ac4992ac024.128x128.png',
#      'item_name': 'Piercing Navigator',
#      'id': '58f0ee99aa4b70452a173073',
#      'url_name': 'piercing_navigator'},
#     {'thumb': 'icons/en/thumbs/Smite_Corrupted.423d5c24da5d1afc7e0efe1d91d30544.128x128.png',
#      'item_name': 'Smite Corrupted',
#      'id': '595567c18e34b5ed3cb3d9bc',
#      'url_name': 'smite_corrupted'},
#     {'thumb': 'icons/en/thumbs/Gladiator_Vice.8439406db915505dbb8a387dc6b4e416.128x128.png',
#      'item_name': 'Gladiator Vice',
#      'id': '59dfeb5c115f1d887cfd7ab8',
#      'url_name': 'gladiator_vice'},
#     {'thumb': 'icons/en/thumbs/Vigilante_Pursuit.332dedb5fa7b6edac656a8fd1ad10535.128x128.png',
#      'item_name': 'Vigilante Pursuit',
#      'id': '59dfeb63115f1d887cfd7abc',
#      'url_name': 'vigilante_pursuit'},
#     {'thumb': 'icons/en/thumbs/Augur_Accord.068cadfef07bb4e729df53eb1b2f46db.128x128.png',
#      'item_name': 'Augur Accord',
#      'id': '59dfeb6c115f1d887cfd7abf',
#      'url_name': 'augur_accord'},
#     {'thumb': 'icons/en/thumbs/Radian_Sentirum.fd67dbe87fcedfc1d914bc36ad2cb7eb.128x128.png',
#      'item_name': 'Radian Sentirum',
#      'id': '59eba86952f90ed715e14159',
#      'url_name': 'radian_sentirum'},
#     {'thumb': 'sub_icons/gauntlet_128x128.png',
#      'item_name': 'Furax Wraith Right Gauntlet',
#      'id': '59e91860f25be4e10d36571f',
#      'url_name': 'furax_wraith_right_gauntlet'},
#     {'thumb': 'sub_icons/cerebrum_128x128.png',
#      'item_name': 'Helios Prime Cerebrum',
#      'id': '58b57068eb26db5c31192115',
#      'url_name': 'helios_prime_cerebrum'},
#     {'thumb': 'sub_icons/carapace_128x128.png',
#      'item_name': 'Helios Prime Carapace',
#      'id': '58b57068eb26db5c31192116',
#      'url_name': 'helios_prime_carapace'},
#     {'thumb': 'icons/en/thumbs/Beguiling_Lantern.c3248916b6065e2a6e97151e7cfc912c.128x128.png',
#      'item_name': 'Beguiling Lantern',
#      'id': '58f0ee99aa4b70452a173072',
#      'url_name': 'beguiling_lantern'},
#     {'thumb': 'icons/en/thumbs/Expel_Corrupted.4b08de242283c30a3da17d9336156b3f.128x128.png',
#      'item_name': 'Expel Corrupted',
#      'id': '595567c18e34b5ed3cb3d9bb',
#      'url_name': 'expel_corrupted'},
#     {'thumb': 'icons/en/thumbs/Ballistica_Prime_Set.4ed33348008ace40406d0383f692ecac.128x128.png',
#      'item_name': 'Ballistica Prime Set',
#      'id': '59a5c2565cd9938cfede703e',
#      'url_name': 'ballistica_prime_set'},
#     {'thumb': 'icons/en/thumbs/Small_Mortus_Lungfish.643e073aad881d5fb1a1c4030e633ae1.128x128.png',
#      'item_name': 'Small Mortus Lungfish',
#      'id': '59e6421240c3ee1a65541c55',
#      'url_name': 'small_mortus_lungfish'},
#     {'thumb': 'icons/en/thumbs/Gladiator_Aegis.b090c523158aaeb9625bdca8df150372.128x128.png',
#      'item_name': 'Gladiator Aegis',
#      'id': '59dfeb5c115f1d887cfd7ab3',
#      'url_name': 'gladiator_aegis'},
#     {'thumb': 'icons/en/thumbs/Neutralizing_Justice.07728fc8496c758312e086bb788ad1ea.128x128.png',
#      'item_name': 'Neutralizing Justice',
#      'id': '5911f11d97a0add8e9d5da4d',
#      'url_name': 'neutralizing_justice'},
#     {'thumb': 'icons/en/thumbs/Small_Tralok.de9ba5aaad92e5d956cdb1ccb90dfed7.128x128.png',
#      'item_name': 'Small Tralok',
#      'id': '59e6421740c3ee1a65541c5e',
#      'url_name': 'small_tralok'},
#     {'thumb': 'icons/en/thumbs/Large_Goopolla.5c83088167310b6b97f791e2c2c668a3.128x128.png',
#      'item_name': 'Large Goopolla',
#      'id': '59e6421240c3ee1a65541c5d',
#      'url_name': 'large_goopolla'},
#     {'thumb': 'icons/en/thumbs/Large_Murkray.6a66b4d8ff19458021405e1bca7653ea.128x128.png',
#      'item_name': 'Large Murkray',
#      'id': '59e6421740c3ee1a65541c69',
#      'url_name': 'large_murkray'},
#     {'thumb': 'icons/en/thumbs/Vigilante_Fervor.b9db93a4d9747d176e6b644bb8e86c52.128x128.png',
#      'item_name': 'Vigilante Fervor',
#      'id': '59dfeb63115f1d887cfd7ab9',
#      'url_name': 'vigilante_fervor'},
#     {'thumb': 'sub_icons/generic_stock_128x128.png',
#      'item_name': 'Gorgon Wraith Stock',
#      'id': '591844575c170664fbd37eb6',
#      'url_name': 'gorgon_wraith_stock'},
#     {'thumb': 'sub_icons/string_128x128.png',
#      'item_name': 'Ballistica Prime String',
#      'id': '59a5cd4d5cd9938cfede7045',
#      'url_name': 'ballistica_prime_string'},
#     {'thumb': 'icons/en/thumbs/Furax_Wraith_Set.c460830e1437c5ab3cd37e2ea51b09a9.128x128.png',
#      'item_name': 'Furax Wraith Set',
#      'id': '59e91860f25be4e10d365720',
#      'url_name': 'furax_wraith_set'},
#     {'thumb': 'icons/en/thumbs/Tear_Azurite.e2f857f217db500bb173a7a4e518958e.128x128.png',
#      'item_name': 'Tear Azurite',
#      'id': '59eba86952f90ed715e14155',
#      'url_name': 'tear_azurite'},
#     {'thumb': 'sub_icons/guard_128x128.png',
#      'item_name': 'Silva & Aegis Prime Guard',
#      'id': '592dd262011e88f094afec88',
#      'url_name': 'silva_and_aegis_prime_guard'},
#     {'thumb': 'icons/en/thumbs/Medium_Mortus_Lungfish.643e073aad881d5fb1a1c4030e633ae1.128x128.png',
#      'item_name': 'Medium Mortus Lungfish',
#      'id': '59e6421240c3ee1a65541c56',
#      'url_name': 'medium_mortus_lungfish'},
#     {'thumb': 'icons/en/thumbs/Shotgun_Riven_Mod_(Veiled).efa7515ed4b28b90fcde3b230701034b.128x128.png',
#      'item_name': 'Shotgun Riven Mod (Veiled)',
#      'id': '58701655937cde2c9d378ac2',
#      'url_name': 'shotgun_riven_mod_(veiled)'},
#     {'thumb': 'icons/en/thumbs/Melee_Riven_Mod_(Veiled).efa7515ed4b28b90fcde3b230701034b.128x128.png',
#      'item_name': 'Melee Riven Mod (Veiled)',
#      'id': '595567c18e34b5ed3cb3d9b9',
#      'url_name': 'melee_riven_mod_(veiled)'},
#     {'thumb': 'icons/en/thumbs/Pistol_Riven_Mod_(Veiled).efa7515ed4b28b90fcde3b230701034b.128x128.png',
#      'item_name': 'Pistol Riven Mod (Veiled)',
#      'id': '58701655937cde2c9d378ac3',
#      'url_name': 'pistol_riven_mod_(veiled)'},
#     {'thumb': 'icons/en/thumbs/Spring-Loaded_Blade.da5dd58b47d86b2eebf3f8102124c024.128x128.png',
#      'item_name': 'Spring-Loaded Blade',
#      'id': '59f38f558c202c007335ba66',
#      'url_name': 'spring_loaded_blade'},
#     {'thumb': 'icons/en/thumbs/Kinetic_Diversion.ceeab7b8bfb93395c6ded1223e730aba.128x128.png',
#      'item_name': 'Kinetic Diversion',
#      'id': '59f38f568c202c007335ba67',
#      'url_name': 'kinetic_diversion'},
#     {'thumb': 'icons/en/thumbs/Fateful_Truth.7676a4b419b615a0f254bb7324b5f206.128x128.png',
#      'item_name': 'Fateful Truth',
#      'id': '59f38f588c202c007335ba68',
#      'url_name': 'fateful_truth'},
#     {'thumb': 'icons/en/thumbs/Magus_Cadence.c86f261fe3644b1eb27e22d4a53fa318.128x128.png',
#      'item_name': 'Magus Cadence',
#      'id': '5a0475076c4655012038ddbe',
#      'url_name': 'magus_cadence'},
#     {'thumb': 'icons/en/thumbs/Magus_Vigor.473998d768bd420877df79cdd55c6188.128x128.png',
#      'item_name': 'Magus Vigor',
#      'id': '5a0475086c4655012038ddbf',
#      'url_name': 'magus_vigor'},
#     {'thumb': 'icons/en/thumbs/Exodia_Valor.6944e42105fc09e60c8a843acedfd7cf.128x128.png',
#      'item_name': 'Exodia Valor',
#      'id': '5a0475086c4655012038ddc0',
#      'url_name': 'exodia_valor'},
#     {'thumb': 'icons/en/thumbs/Exodia_Brave.46667ed53d81bf2cc9aacde46019c7e9.128x128.png',
#      'item_name': 'Exodia Brave',
#      'id': '5a0475086c4655012038ddc1',
#      'url_name': 'exodia_brave'},
#     {'thumb': 'icons/en/thumbs/Exodia_Hunt.991da5e49a00e69755b5c7948f5448f6.128x128.png',
#      'item_name': 'Exodia Hunt',
#      'id': '5a0475096c4655012038ddc2',
#      'url_name': 'exodia_hunt'},
#     {'thumb': 'icons/en/thumbs/Exodia_Triumph.fe6f1256127be984a80deb48afd26faa.128x128.png',
#      'item_name': 'Exodia Triumph',
#      'id': '5a0475096c4655012038ddc3',
#      'url_name': 'exodia_triumph'},
#     {'thumb': 'icons/en/thumbs/Magus_Nourish.a33f07304a72500072d20d13258e119b.128x128.png',
#      'item_name': 'Magus Nourish',
#      'id': '5a0475096c4655012038ddc4',
#      'url_name': 'magus_nourish'},
#     {'thumb': 'icons/en/thumbs/Virtuos_Shadow.b6be77f2f40f28d66c86674233faea4d.128x128.png',
#      'item_name': 'Virtuos Shadow',
#      'id': '5a04750a6c4655012038ddc5',
#      'url_name': 'virtuos_shadow'},
#     {'thumb': 'icons/en/thumbs/Virtuos_Fury.f71902bf678d290ad03b625dc35834ca.128x128.png',
#      'item_name': 'Virtuos Fury',
#      'id': '5a04750a6c4655012038ddc6',
#      'url_name': 'virtuos_fury'},
#     {'thumb': 'icons/en/thumbs/Virtuos_Null.e3f5a968f4b41d236acad8c9efb8cfef.128x128.png',
#      'item_name': 'Virtuos Null',
#      'id': '5a04750a6c4655012038ddc7',
#      'url_name': 'virtuos_null'},
#     {'thumb': 'icons/en/thumbs/Virtuos_Tempo.6e63273510b1ba372aa7eaccfce695e2.128x128.png',
#      'item_name': 'Virtuos Tempo',
#      'id': '5a04750b6c4655012038ddc8',
#      'url_name': 'virtuos_tempo'},
#     {'thumb': 'icons/en/thumbs/Exodia_Force.3777cf3132503f972624ac56c1731743.128x128.png',
#      'item_name': 'Exodia Force',
#      'id': '5a04750b6c4655012038ddc9',
#      'url_name': 'exodia_force'},
#     {'thumb': 'icons/en/thumbs/Virtuos_Ghost.1bf1c1292e89b66f607c9955ea78b1cb.128x128.png',
#      'item_name': 'Virtuos Ghost',
#      'id': '5a04750e6c4655012038ddd0',
#      'url_name': 'virtuos_ghost'},
#     {'thumb': 'sub_icons/blade_128x128.png',
#      'item_name': 'Ankyros Prime Blade',
#      'id': '54a73e65e779893a797fff24',
#      'url_name': 'ankyros_prime_blade'},
#     {'thumb': 'sub_icons/gauntlet_128x128.png',
#      'item_name': 'Ankyros Prime Gauntlet',
#      'id': '54a73e65e779893a797fff26',
#      'url_name': 'ankyros_prime_gauntlet'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Bo Prime Blueprint',
#      'id': '54a73e65e779893a797fff27',
#      'url_name': 'bo_prime_blueprint'},
#     {'thumb': 'sub_icons/handle_128x128.png',
#      'item_name': 'Bo Prime Handle',
#      'id': '54a73e65e779893a797fff28',
#      'url_name': 'bo_prime_handle'},
#     {'thumb': 'sub_icons/ornament_128x128.png',
#      'item_name': 'Bo Prime Ornament',
#      'id': '54a73e65e779893a797fff29',
#      'url_name': 'bo_prime_ornament'},
#     {'thumb': 'sub_icons/handle_128x128.png',
# ...
#      'item_name': 'Meteor Munitions',
#      'id': '567af35fcbfa8f05d076a4e0',
#      'url_name': 'meteor_munitions'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Boar Prime Stock',
#      'id': '54a73e65e779893a797fff2d',
#      'url_name': 'boar_prime_stock'},
#     {'thumb': 'icons/en/thumbs/Momentary_Pause.4c78463a142485281c4b5b784ca30d0d.128x128.png',
#      'item_name': 'Momentary Pause',
#      'id': '567af35fcbfa8f05d076a4e1',
#      'url_name': 'momentary_pause'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Boltor Prime Barrel',
#      'id': '54a73e65e779893a797fff2e',
#      'url_name': 'boltor_prime_barrel'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Boltor Prime Blueprint',
#      'id': '54a73e65e779893a797fff2f',
#      'url_name': 'boltor_prime_blueprint'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Boltor Prime Receiver',
#      'id': '54a73e65e779893a797fff30',
#      'url_name': 'boltor_prime_receiver'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Boltor Prime Stock',
#      'id': '54a73e65e779893a797fff31',
#      'url_name': 'boltor_prime_stock'},
#     {'thumb': 'icons/en/thumbs/Night_Stalker.e3f83458b9a79243df2613bf3d334861.128x128.png',
#      'item_name': 'Night Stalker',
#      'id': '567af35fcbfa8f05d076a4e2',
#      'url_name': 'night_stalker'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Braton Prime Barrel',
#      'id': '54a73e65e779893a797fff32',
#      'url_name': 'braton_prime_barrel'},
#     {'thumb': 'icons/en/thumbs/Overcharged.e8dfb3f7bb67ad9b3628d6932a427d46.128x128.png',
#      'item_name': 'Overcharged',
#      'id': '567af35fcbfa8f05d076a4e3',
#      'url_name': 'overcharged'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Braton Prime Blueprint',
#      'id': '54a73e65e779893a797fff33',
#      'url_name': 'braton_prime_blueprint'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Braton Prime Receiver',
#      'id': '54a73e65e779893a797fff34',
#      'url_name': 'braton_prime_receiver'},
#     {'thumb': 'icons/en/thumbs/Overcharge_Detectors.b9a371b79d26b7eb4a755729147a8ca7.128x128.png',
#      'item_name': 'Overcharge Detectors',
#      'id': '567af35fcbfa8f05d076a4e4',
#      'url_name': 'overcharge_detectors'},
#     {'thumb': 'icons/en/thumbs/Overview.aabf5882efc4a17d3640cab34dc091b6.128x128.png',
#      'item_name': 'Overview',
#      'id': '567af35fcbfa8f05d076a4e5',
#      'url_name': 'overview'},
#     {'thumb': 'icons/en/thumbs/Prize_Kill.e3319fbe68882457f6ba2a167d2121d2.128x128.png',
#      'item_name': 'Prize Kill',
#      'id': '567af35fcbfa8f05d076a4e6',
#      'url_name': 'prize_kill'},
#     {'thumb': 'icons/en/thumbs/Quick_Charge.428d4d450889ea8e92b0fe22e0aea38a.128x128.png',
#      'item_name': 'Quick Charge',
#      'id': '567af35fcbfa8f05d076a4e7',
#      'url_name': 'quick_charge'},
#     {'thumb': 'icons/en/thumbs/Razor_Munitions.83cd92fcf1aa1ca8eaccb6f27d28f30b.128x128.png',
#      'item_name': 'Razor Munitions',
#      'id': '567af35fcbfa8f05d076a4e8',
#      'url_name': 'razor_munitions'},
#     {'thumb': 'icons/en/thumbs/Recover.e69c0a870f45b50e769fc05455a43a3f.128x128.png',
#      'item_name': 'Recover',
#      'id': '567af35fcbfa8f05d076a4e9',
#      'url_name': 'recover'},
#     {'thumb': 'icons/en/thumbs/Recuperate.ae5fec3f7c795bb2035fba9441f27a5d.128x128.png',
#      'item_name': 'Recuperate',
#      'id': '567af35fcbfa8f05d076a4ea',
#      'url_name': 'recuperate'},
#     {'thumb': 'icons/en/thumbs/Reflex_Draw.e95db6d97921880fd32fcbdf537c65a9.128x128.png',
#      'item_name': 'Reflex Draw',
#      'id': '567af35fcbfa8f05d076a4eb',
#      'url_name': 'reflex_draw'},
#     {'thumb': 'icons/en/thumbs/Relentless_Assault.1f785af43c72d1287936e6791314a9cc.128x128.png',
#      'item_name': 'Relentless Assault',
#      'id': '567af35fcbfa8f05d076a4ec',
#      'url_name': 'relentless_assault'},
#     {'thumb': 'icons/en/thumbs/Ripper_Rounds.b14591b6f15dcf7aba2a721201fd706e.128x128.png',
#      'item_name': 'Ripper Rounds',
#      'id': '567af35fcbfa8f05d076a4ee',
#      'url_name': 'ripper_rounds'},
#     {'thumb': 'icons/en/thumbs/Rising_Skill.949f1c9112ed0168fc73027fae5449c7.128x128.png',
#      'item_name': 'Rising Skill',
#      'id': '567af35fcbfa8f05d076a4ef',
#      'url_name': 'rising_skill'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Braton Prime Stock',
#      'id': '54a73e65e779893a797fff35',
#      'url_name': 'braton_prime_stock'},
#     {'thumb': 'icons/en/thumbs/Searing_Leap.49e5b609935a9d61587e14ac7a729f85.128x128.png',
#      'item_name': 'Searing Leap',
#      'id': '567af35fcbfa8f05d076a4f0',
#      'url_name': 'searing_leap'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Bronco Prime Barrel',
#      'id': '54a73e65e779893a797fff36',
#      'url_name': 'bronco_prime_barrel'},
#     {'thumb': 'icons/en/thumbs/Serrated_Edges.7734d4b5eca3d49886694329157f1d74.128x128.png',
#      'item_name': 'Serrated Edges',
#      'id': '567af35fcbfa8f05d076a4f1',
#      'url_name': 'serrated_edges'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Bronco Prime Blueprint',
#      'id': '54a73e65e779893a797fff37',
#      'url_name': 'bronco_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Serrated_Rounds.e2d6ee028dbe85ce258f142b8fc9b072.128x128.png',
#      'item_name': 'Serrated Rounds',
#      'id': '567af35fcbfa8f05d076a4f2',
#      'url_name': 'serrated_rounds'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Bronco Prime Receiver',
#      'id': '54a73e65e779893a797fff38',
#      'url_name': 'bronco_prime_receiver'},
#     {'thumb': 'icons/en/thumbs/Sharpened_Blade.d41298d6bb8919cb55975048c052a5bf.128x128.png',
#      'item_name': 'Sharpened Blade',
#      'id': '567af35fcbfa8f05d076a4f3',
#      'url_name': 'sharpened_blade'},
#     {'thumb': 'icons/en/thumbs/Shred_Shot.6c54abde2f2a72ce7c5b88ac37500cc3.128x128.png',
#      'item_name': 'Shred Shot',
#      'id': '567af35fcbfa8f05d076a4f4',
#      'url_name': 'shred_shot'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Burston Prime Barrel',
#      'id': '54a73e65e779893a797fff39',
#      'url_name': 'burston_prime_barrel'},
#     {'thumb': 'icons/en/thumbs/Snap_Shot.7832d651c7914eab0ccfc4385acf34b1.128x128.png',
#      'item_name': 'Snap Shot',
#      'id': '567af35fcbfa8f05d076a4f5',
#      'url_name': 'snap_shot'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Burston Prime Blueprint',
#      'id': '54a73e65e779893a797fff3a',
#      'url_name': 'burston_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Soft_Hands.e2a9bbcfc25d142c9c11704363c5b0dd.128x128.png',
#      'item_name': 'Soft Hands',
#      'id': '567af35fcbfa8f05d076a4f6',
#      'url_name': 'soft_hands'},
#     {'thumb': 'icons/en/thumbs/Spring-Loaded_Broadhead.8457bdc8b1bcad57c7c22fb94bd5bebd.128x128.png',
#      'item_name': 'Spring-Loaded Broadhead',
#      'id': '567af35fcbfa8f05d076a4f7',
#      'url_name': 'spring_loaded_broadhead'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Burston Prime Receiver',
#      'id': '54a73e65e779893a797fff3b',
#      'url_name': 'burston_prime_receiver'},
#     {'thumb': 'icons/en/thumbs/Spry_Sights.8454c05d30b9cadf5af2a6b24024ee1d.128x128.png',
#      'item_name': 'Spry Sights',
#      'id': '567af35fcbfa8f05d076a4f8',
#      'url_name': 'spry_sights'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Burston Prime Stock',
#      'id': '54a73e65e779893a797fff3c',
#      'url_name': 'burston_prime_stock'},
#     {'thumb': 'sub_icons/blade_128x128.png',
#      'item_name': 'Dakra Prime Blade',
#      'id': '54a73e65e779893a797fff3d',
#      'url_name': 'dakra_prime_blade'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Dakra Prime Blueprint',
#      'id': '54a73e65e779893a797fff3e',
#      'url_name': 'dakra_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Stand_Ground.363d438b54e942781d9db3665d197a59.128x128.png',
#      'item_name': 'Stand Ground',
#      'id': '567af35fcbfa8f05d076a4f9',
#      'url_name': 'stand_ground'},
#     {'thumb': 'sub_icons/blade_128x128.png',
#      'item_name': 'Fang Prime Blade',
#      'id': '54a73e65e779893a797fff40',
#      'url_name': 'fang_prime_blade'},
#     {'thumb': 'icons/en/thumbs/Strafing_Slide.7c339df1175de65544fdabd98bad1310.128x128.png',
#      'item_name': 'Strafing Slide',
#      'id': '567af35fcbfa8f05d076a4fa',
#      'url_name': 'strafing_slide'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Fang Prime Blueprint',
#      'id': '54a73e65e779893a797fff41',
#      'url_name': 'fang_prime_blueprint'},
#     {'thumb': 'sub_icons/blade_128x128.png',
#      'item_name': 'Glaive Prime Blade',
#      'id': '54a73e65e779893a797fff43',
#      'url_name': 'glaive_prime_blade'},
#     {'thumb': 'icons/en/thumbs/Surplus_Diverters.09029ac49b2910d44f759dd05afc889e.128x128.png',
#      'item_name': 'Surplus Diverters',
#      'id': '567af35fcbfa8f05d076a4fb',
#      'url_name': 'surplus_diverters'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Glaive Prime Blueprint',
#      'id': '54a73e65e779893a797fff44',
#      'url_name': 'glaive_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Sword_Alone.1c6ec66a54c742480eb3bee11e56ea72.128x128.png',
#      'item_name': 'Sword Alone',
#      'id': '567af35fcbfa8f05d076a4fc',
#      'url_name': 'sword_alone'},
#     {'thumb': 'sub_icons/disc_128x128.png',
#      'item_name': 'Glaive Prime Disc',
#      'id': '54a73e65e779893a797fff45',
#      'url_name': 'glaive_prime_disc'},
#     {'thumb': 'icons/en/thumbs/Tactical_Reload.2ac877a6d2e8459575098a219e59b36e.128x128.png',
#      'item_name': 'Tactical Reload',
#      'id': '567af35fcbfa8f05d076a4fd',
#      'url_name': 'tactical_reload'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Hikou Prime Blueprint',
#      'id': '54a73e65e779893a797fff46',
#      'url_name': 'hikou_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Tear_Gas.dabcc0fbb32e0b6fb9188fd034fd6807.128x128.png',
#      'item_name': 'Tear Gas',
#      'id': '567af35fcbfa8f05d076a4fe',
#      'url_name': 'tear_gas'},
#     {'thumb': 'sub_icons/stars_128x128.png',
#      'item_name': 'Hikou Prime Stars',
#      'id': '54a73e65e779893a797fff48',
#      'url_name': 'hikou_prime_stars'},
#     {'thumb': 'icons/en/thumbs/Tempered_Bound.cdc7368fa20d61eaecae92f5527dfb18.128x128.png',
#      'item_name': 'Tempered Bound',
#      'id': '567af35fcbfa8f05d076a4ff',
#      'url_name': 'tempered_bound'},
#     {'thumb': 'icons/en/thumbs/Focused_Acceleration.e88467c7ccf1bb5e14ec85ce5ec0e816.128x128.png',
#      'item_name': 'Focused Acceleration',
#      'id': '567af35fcbfa8f05d076a50c',
#      'url_name': 'focused_acceleration'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Latron Prime Blueprint',
#      'id': '54a73e65e779893a797fff4a',
#      'url_name': 'latron_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Full_Capacity.3487f8c1a516c44d36d4655604875586.128x128.png',
#      'item_name': 'Full Capacity',
#      'id': '567af35fcbfa8f05d076a50d',
#      'url_name': 'full_capacity'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Latron Prime Receiver',
#      'id': '54a73e65e779893a797fff4b',
#      'url_name': 'latron_prime_receiver'},
#     {'thumb': 'icons/en/thumbs/Gorgon_Frenzy.0993e71e3c052de71d6bfe993c4076f7.128x128.png',
#      'item_name': 'Gorgon Frenzy',
#      'id': '567af35fcbfa8f05d076a50e',
#      'url_name': 'gorgon_frenzy'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Latron Prime Stock',
#      'id': '54a73e65e779893a797fff4c',
#      'url_name': 'latron_prime_stock'},
#     {'thumb': 'icons/en/thumbs/Grinloked.a9052cbab7dc1518e74b3e5c2e3abf14.128x128.png',
#      'item_name': 'Grinloked',
#      'id': '567af35fcbfa8f05d076a50f',
#      'url_name': 'grinloked'},
#     {'thumb': 'icons/en/thumbs/Hastened_Steps.8cad83d07e5da2f97087ef18013d20b2.128x128.png',
#      'item_name': 'Hastened Steps',
#      'id': '567af35fcbfa8f05d076a510',
#      'url_name': 'hastened_steps'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Lex Prime Barrel',
#      'id': '54a73e65e779893a797fff4d',
#      'url_name': 'lex_prime_barrel'},
#     {'thumb': 'icons/en/thumbs/Heavy_Warhead.f6463d740768ab98091869aa34de1698.128x128.png',
#      'item_name': 'Heavy Warhead',
#      'id': '567af35fcbfa8f05d076a511',
#      'url_name': 'heavy_warhead'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Lex Prime Blueprint',
#      'id': '54a73e65e779893a797fff4e',
#      'url_name': 'lex_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Heightened_Reflexes.e303a65658bac2a06e0681ee8cdf3483.128x128.png',
#      'item_name': 'Heightened Reflexes',
#      'id': '567af35fcbfa8f05d076a512',
#      'url_name': 'heightened_reflexes'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Orthos Prime Blueprint',
#      'id': '54a73e65e779893a797fff51',
#      'url_name': 'orthos_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Loose_Magazine.0428fe78b8c7fa59ecd2861e1c3711b7.128x128.png',
#      'item_name': 'Loose Magazine',
#      'id': '567af35fcbfa8f05d076a51a',
#      'url_name': 'loose_magazine'},
#     {'thumb': 'sub_icons/grip_128x128.png',
#      'item_name': 'Paris Prime Grip',
#      'id': '54a73e65e779893a797fff53',
#      'url_name': 'paris_prime_grip'},
#     {'thumb': 'icons/en/thumbs/Lucky_Shot.7e508641f4f2b24459547f38d9361de8.128x128.png',
#      'item_name': 'Lucky Shot',
#      'id': '567af35fcbfa8f05d076a51b',
#      'url_name': 'lucky_shot'},
#     {'thumb': 'icons/en/thumbs/Maximum_Capacity.622ba4b0a9f284006d04dc5784e8f8af.128x128.png',
#      'item_name': 'Maximum Capacity',
#      'id': '567af35fcbfa8f05d076a51c',
#      'url_name': 'maximum_capacity'},
#     {'thumb': 'sub_icons/string_128x128.png',
#      'item_name': 'Paris Prime String',
#      'id': '54a73e65e779893a797fff56',
#      'url_name': 'paris_prime_string'},
#     {'thumb': 'sub_icons/handle_128x128.png',
#      'item_name': 'Reaper Prime Handle',
#      'id': '54a73e65e779893a797fff5a',
#      'url_name': 'reaper_prime_handle'},
#     {'thumb': 'icons/en/thumbs/Mortal_Conduct.1891d5e6d5e0cb468f6d0947d91bf260.128x128.png',
#      'item_name': 'Mortal Conduct',
#      'id': '567af35fcbfa8f05d076a51e',
#      'url_name': 'mortal_conduct'},
#     {'thumb': 'sub_icons/barrel_128x128.png',
#      'item_name': 'Sicarus Prime Barrel',
#      'id': '54a73e65e779893a797fff5e',
#      'url_name': 'sicarus_prime_barrel'},
#     {'thumb': 'icons/en/thumbs/Plan_B.97f0cc8968aace82c1b9a54d29997581.128x128.png',
#      'item_name': 'Plan B',
#      'id': '567af35fcbfa8f05d076a51f',
#      'url_name': 'plan_b'},
#     {'thumb': 'sub_icons/blueprint_128x128.png',
#      'item_name': 'Sicarus Prime Blueprint',
#      'id': '54a73e65e779893a797fff5f',
#      'url_name': 'sicarus_prime_blueprint'},
#     {'thumb': 'icons/en/thumbs/Argon_Scope.f59f66183ee3f605c51f28d68dfa6714.128x128.png',
#      'item_name': 'Argon Scope',
#      'id': '56a7b2741133f656cb085d8a',
#      'url_name': 'argon_scope'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Sicarus Prime Receiver',
#      'id': '54a73e65e779893a797fff60',
#      'url_name': 'sicarus_prime_receiver'},
#     {'thumb': 'icons/en/thumbs/Sharpened_Bullets.e2574bfc3a35927af69218dd4f48a6f6.128x128.png',
#      'item_name': 'Sharpened Bullets',
#      'id': '56a7b2801133f656cb085d8c',
#      'url_name': 'sharpened_bullets'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Soma Prime Receiver',
#      'id': '54a73e65e779893a797fff63',
#      'url_name': 'soma_prime_receiver'},
#     {'thumb': 'sub_icons/stock_128x128.png',
#      'item_name': 'Soma Prime Stock',
#      'id': '54a73e65e779893a797fff64',
#      'url_name': 'soma_prime_stock'},
#     {'thumb': 'icons/en/thumbs/Health_Conversion.9d00e60accdfe2bf5185ed7669a92a88.128x128.png',
#      'item_name': 'Health Conversion',
#      'id': '56dac8d25cc639de0a45c52d',
#      'url_name': 'health_conversion'},
#     {'thumb': 'sub_icons/receiver_128x128.png',
#      'item_name': 'Vasto Prime Receiver',
#      'id': '54a73e65e779893a797fff67',
#      'url_name': 'vasto_prime_receiver'},
#     ...]}}}

# %% [markdown]
# #### Create items table

# %%
# Create 'items' table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS items (
    item_id VARCHAR(255) NOT NULL PRIMARY KEY,
    item_name VARCHAR(255),
    url_name VARCHAR(255))
    """)
    conn.commit()
except:
    conn.rollback()

# Populate table 'items' with item JSON data
for item in items["payload"]["items"]["en"]:
    try:
        x.execute(
        """
        INSERT INTO items (item_id, item_name, url_name)
        VALUES (%s, %s, %s)
        """, [item["id"], item["item_name"], item["url_name"]])
        conn.commit()
    except:
        conn.rollback()
# Out:
# C:\Users\Christopher Wong\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: Warning: (1050, "Table 'items' already exists")
#   if __name__ == '__main__':

# %% [markdown]
# #### Now we want to get the item information for each item.
# After a quick manual inspection, we find that different items have different dictionary headers. Thus, we need to find all possible dictionary headers for every item.

# %%
# Using time.sleep to not flood API requests. Recommend 3 requests per second
import time

# Using set because we want only unique elements
all_keys = set([])

############################################################################
# HEY YO, THIS TAKES LIKE 25 MINUTES TO RUN SO DON'T USE IT MORE THAN ONCE #
############################################################################

# Get all dictionary keys from JSON for all items
for item in items["payload"]["items"]["en"]:
    # Url switch-a-roo that goes through all item urls
    url_name = item["url_name"]
    req = s.get("https://api.warframe.market/v1/items/" + url_name).json()
    # Grabs all the dictionary keys from each item page
    for item_in_set in req["payload"]["item"]["items_in_set"]:
        for key in list(item_in_set.keys()):
            all_keys.add(key)
    
    # I use 2 requests per second max
    time.sleep(0.5)
    
all_keys
# Out:
# {'de',
#  'ducats',
#  'en',
#  'fr',
#  'icon',
#  'icon_format',
#  'id',
#  'ko',
#  'mastery_level',
#  'mod_max_rank',
#  'rarity',
#  'ru',
#  'set_root',
#  'sub_icon',
#  'sv',
#  'tags',
#  'thumb',
#  'trading_tax',
#  'url_name',
#  'zh'}

# %% [markdown]
# We see that "tags" are a many-to-many relationship with items, as well as "drop" in the "en" header. Thus, we also need to find all tags and drops in our data. We do this so we can use a 3-table design with a bridge table to nicely store our many-to-many relationships.

# %%
# Using set because we want only unique elements
all_tags = set([])

############################################################################
# HEY YO, THIS TAKES LIKE 25 MINUTES TO RUN SO DON'T USE IT MORE THAN ONCE #
############################################################################

# Get all tags
for item in items["payload"]["items"]["en"]:
    # Url switch-a-roo that goes through all item urls
    url_name = item["url_name"]
    req = s.get("https://api.warframe.market/v1/items/" + url_name).json()
    # Grabs all tags from each item page
    for item_in_set in req["payload"]["item"]["items_in_set"]:
        for tag in item_in_set["tags"]:
            all_tags.add(tag)
    
    # I use 2 requests per second max
    time.sleep(0.5)
    
all_tags
# Out:
# {'Melee',
#  'adarza',
#  'arcane enhancements',
#  'arcane helmets',
#  'arch-melee',
#  'archwing',
#  'archwing gun',
#  'archwing melee',
#  'assault rifle',
#  'augur',
#  'aura',
#  'avionics',
#  'ayatan',
#  'band',
#  'barrel',
#  'beacon',
#  'beast',
#  'blade',
#  'blade and whip',
#  'blueprint',
#  'boot',
#  'bow',
#  'buckle',
#  'carapace',
#  'cerebrum',
#  'chassis',
#  'chesa',
#  'chroma',
#  'claws',
#  'collectible',
#  'common',
#  'commonuncommonrare',
#  'companion',
#  'conclave',
#  'crossbow',
#  'dagger',
#  'daggers',
#  'dethcube',
#  'detron',
#  'disc',
#  'dual',
#  'dual swords',
#  'engines',
#  'excalibur',
#  'exilus',
#  'fish',
#  'fist',
#  'flamethrower',
#  'focus lens',
#  'frost',
#  'fuselage',
#  'fusion core',
#  'gara',
#  'garuda',
#  'gauntlet',
#  'gems',
#  'gladiator',
#  'glaives',
#  'grakata',
#  'grip',
#  'gunblade',
#  'hammers',
#  'handle',
#  'harness',
#  'harrow',
#  'head',
#  'heatsink',
#  'helmet',
#  'helminth charger',
#  'hilt',
#  'huras',
#  'hydroid',
#  'imprint',
#  'inaros',
#  'ivara',
#  'k-drive',
#  'kavat',
#  'key',
#  'khora',
#  'kitgun',
#  'kubrow',
#  'kunai',
#  'landing craft',
#  'lanka',
#  'legendary',
#  'lens',
#  'link',
#  'loki',
#  'lower limb',
#  'machete',
#  'mag',
#  'melee',
#  'misc',
#  'miter',
#  'mod',
#  'motor',
#  'mutalist_quanta',
#  'neuroptics',
#  'nezha',
#  'nidus',
#  'nova',
#  'nunchakus',
#  'obex',
#  'octavia',
#  'operator',
#  'ornament',
#  'panthera',
#  'parkour',
#  'parts',
#  'peculiar',
#  'penta',
#  'pistol',
#  'polearms',
#  'pouch',
#  'primary',
#  'prime',
#  'prova',
#  'pve',
#  'pvp',
#  'quest',
#  'raksa',
#  'rare',
#  'receiver',
#  'revenant',
#  'rhino',
#  'rifle',
#  'riven',
#  'sahasa',
#  'scene',
#  'sculpture',
#  'secondary',
#  'sentinel',
#  'set',
#  'shade',
#  'shot gun',
#  'shotgun',
#  'silva & aegis',
#  'smeeta',
#  'sniper',
#  'sparring',
#  'special weapons',
#  'stance',
#  'star',
#  'stars',
#  'staves',
#  'stock',
#  'string',
#  'sunika',
#  'sword and shield',
#  'swords',
#  'syndicate',
#  'systems',
#  'tatsu',
#  'taxon',
#  'tetra',
#  'titania',
#  'tonfas',
#  'transmute core',
#  'triangulator',
#  'umbra',
#  'uncommon',
#  'unique',
#  'upper limb',
#  'vandal',
#  'vigilante',
#  'void key',
#  'void relic',
#  'void trader',
#  'volt',
#  'warfans',
#  'warframe',
#  'weapon',
#  'weapons',
#  'whips',
#  'wings',
#  'wukong',
#  'zaw'}

# %%
# Using set because we want only unique elements
all_drops = set([])

############################################################################
# HEY YO, THIS TAKES LIKE 25 MINUTES TO RUN SO DON'T USE IT MORE THAN ONCE #
############################################################################

# Get all drops
for item in items["payload"]["items"]["en"]:
    # Url switch-a-roo that goes through all item urls
    url_name = item["url_name"]
    req = s.get("https://api.warframe.market/v1/items/" + url_name).json()
    # Grabs all drops from each item page
    for item_in_set in req["payload"]["item"]["items_in_set"]:
        # Check if drop header exists
        if "drop" in item_in_set["en"]:
            for drop in item_in_set["en"]["drop"]:
                all_drops.add(drop["name"])
                
    # I use 2 requests per second max
    time.sleep(0.5)
    
all_drops
# Out:
# {', Syrtis (Exterminate)',
#  '002-ER (1.25%)',
#  '17 points inOperation Breeding Grounds',
#  '3rd Exterminate Cache , 10.79%',
#  'Aerial Commander (0.02%)',
#  'Aerial Commander (0.33%)',
#  'Aerial Commander (1.14%)',
#  'Alad V',
#  'Alert Nightmare Mission',
#  'Alerts',
#  'Ambulas',
#  'Ancient Disruptor',
#  'Angst',
#  'Arbiters of Hexis',
#  'Arbiters of Hexis ',
#  'Arbiters of Hexis Offering',
#  'Arbitrations',
#  'Archwing Interception Reward',
#  'Archwing Mobile Defense (Neptune, Salacia)Archwing Sabotage Reward',
#  'Archwing Mobile Defense Reward',
#  'Archwing Mobile Defense RewardArchwing Sabotage Reward',
#  'Archwing Sabotage Reward',
#  'ArchwingEximus',
#  'Armis Ulta (1.25%)',
#  'Auditor',
#  'Auditor (1.25%)',
#  'Augustus, Mars Corpus T1Interception',
#  'Axi A1 Common',
#  'Axi A1 Rare',
#  'Axi A1 Uncommon',
#  'Axi A2 Rare',
#  'Axi A2 Uncommon',
#  'Axi A3 Common',
#  'Axi A3 Rare',
#  'Axi A3 Uncommon',
#  'Axi A5 Rare',
#  'Axi A5 Uncommon',
#  'Axi B1 Common',
#  'Axi B1 Rare',
#  'Axi B2 Common',
#  'Axi B2 Rare',
#  'Axi C1 Rare',
#  'Axi C2 Uncommon',
#  'Axi C3 Rare',
#  'Axi E2 Rare',
#  'Axi G1 Common',
#  'Axi G1 Rare',
#  'Axi G1 Uncommon',
#  'Axi H1 Rare',
#  'Axi H2 Common',
#  'Axi H2 Rare',
#  'Axi H3 Common',
#  'Axi H3 Rare',
#  'Axi H4 Common',
#  'Axi K1 Common',
#  'Axi K1 Rare',
#  'Axi K1 Uncommon',
#  'Axi K2 Rare',
#  'Axi K3 Uncommon',
#  'Axi K5 Uncommon (11%)',
#  'Axi L2 Rare',
#  'Axi L3 Uncommon',
#  'Axi N1 Common',
#  'Axi N1 Rare',
#  'Axi N1 Uncommon',
#  'Axi N2 Common',
#  'Axi N2 Rare',
#  'Axi N2 Uncommon',
#  'Axi N3 Common',
#  'Axi N3 Rare',
#  'Axi N3 Uncommon',
#  'Axi N4 Common',
#  'Axi N4 Rare',
#  'Axi N4 Uncommon',
#  'Axi N5 Common',
#  'Axi N5 Rare',
#  'Axi N5 Uncommon',
#  'Axi O1 Common',
#  'Axi O1 Rare',
#  'Axi O2 Uncommon',
#  'Axi O3 Common',
#  'Axi O4 Uncommon',
#  'Axi R2 Rare',
#  'Axi S1 Common',
#  'Axi S1 Rare',
#  'Axi S1 Uncommon',
#  'Axi T1 Common',
#  'Axi T1 Rare',
#  'Axi T1 Uncommon',
#  'Axi T2 Rare (2%)',
#  'Axi T2 Uncommon (25.3%)',
#  'Axi V1 Common',
#  'Axi V1 Rare',
#  'Axi V1 Uncommon',
#  'Axi V2 Common',
#  'Axi V2 Rare',
#  'Axi V2 Uncommon',
#  'Axi V3 Common',
#  'Axi V3 Rare',
#  'Axi V3 Uncommon',
#  'Axi V4 Uncommon',
#  'Axi V5 Common',
#  'Axi V5 Rare',
#  'Axi V7 Uncommon',
#  'Axi V8 Rare',
#  'Axi V8 Uncommon',
#  'Azoth',
#  'Azoth (1.25%)',
#  'Ballista',
#  "Baro Ki'Teer",
#  'Battalyst',
#  'Boiler',
#  'Bounty (20-40 )',
#  'Bounty (20-40)',
#  'Bounty (20-40, 30-50)',
#  'Bounty (30-50 )',
#  'Bounty (30-50)',
#  'Bounty (40-60)',
#  'Brood Mother',
#  'Caelus,Uranus Interception Reward',
#  'Captain Vor',
#  'Captain Vor (Corrupted)',
#  'Cephalon Simaris',
#  'Cephalon Simaris Offering',
#  'Cephalon Suda',
#  'Cephalon Suda Offering',
#  'Conclave',
#  'Conclave Battle Rewards',
#  'Conclave Mission Reward',
#  'Conclave Offering',
#  'Conclave Weekly Challenges',
#  'Conculyst',
#  'Coolant Raknoid (0.97%)',
#  'Corpus Archwing Exterminate Reward',
#  'Corpus Archwing Mobile Defense Reward',
#  'Corpus Archwing Sabotage Reward',
#  'Corpus T3Defense Reward',
#  'Corpus Tech',
#  'Corpus Tier 3Defense Reward',
#  'Corpus Warden',
#  'CorpusAnti MOA',
#  'CorpusAttack Drone',
#  'CorpusCarrier (Enemy)',
#  'CorpusComba',
#  'CorpusCorvette',
#  'CorpusCrewman',
#  'CorpusDatalyst',
#  'CorpusDenial Bursa',
#  'CorpusDetron Crewman',
#  'CorpusDrone',
#  'CorpusDrover Bursa',
#  'CorpusElite Crewman',
#  'CorpusFrigate',
#  'CorpusFusion MOA',
#  'CorpusGox',
#  'CorpusIsolator Bursa',
#  'CorpusJackal',
#  'CorpusLeech Osprey',
#  'CorpusLocust Drone',
#  'CorpusLynx Osprey',
#  'CorpusLynx Turret',
#  'CorpusMOA',
#  'CorpusMine Osprey',
#  'CorpusNemes',
#  'CorpusNullifier Crewman',
#  'CorpusOxium Osprey',
#  'CorpusPenta Ranger',
#  'CorpusPower Carrier',
#  'CorpusProd Crewman',
#  'CorpusQuanta Ranger',
#  'CorpusRailgun MOA',
#  'CorpusRanger',
#  'CorpusRazorback',
#  'CorpusSapping Osprey',
#  'CorpusScavenger Drone',
#  'CorpusScrambus',
#  'CorpusShield Osprey',
#  'CorpusShockwave MOA',
#  'CorpusSniper Crewman',
#  'CorpusTech',
#  'Corrupted Ancient',
#  'Corrupted Bombard',
#  'Corrupted Butcher',
#  'Corrupted Butcher (1.14%)',
#  'Corrupted Crewman',
#  'Corrupted Heavy Gunner',
#  'Corrupted Lancer',
#  'Corrupted Lancer (1.14%)',
#  'Corrupted MOA',
#  'Corrupted Nullifier',
#  'Corrupted Warden',
#  'Councilor Vay Hek',
#  'Crawler',
#  'Dakata, Kuva Fortress.',
#  'Dark Sector Defense',
#  'Dark Sector Rewards Rotation B',
#  'Dark Sector Rewards Rotation C',
#  'Dark Sector Survival Reward',
#  'Dark Sectors Defense Reward',
#  'Dark Sectors Defense on Mars Reward',
#  'Dark Sectors Excavation Reward',
#  'Dark Sectors Survival Reward',
#  'Defection (T1, T2, T3)',
#  'Defection Reward',
#  'Defense Reward',
#  'Defense Tier 2',
#  'Derim Zahn',
#  'Derim Zahn (1.25%)',
#  'Destreza Finesse Bundle',
#  'Drahk',
#  'Drekar BallistaSabotage Uranus',
#  'Drekar Butcher',
#  'Drekar Elite Lancer',
#  'Drekar EvisceratorSabotage Uranus',
#  'Drekar Heavy GunnerSabotage Uranus',
#  'Drekar Hellion',
#  'Drekar HellionSabotage on Uranus',
#  'Drekar Lancer',
#  'Drekar Seeker',
#  'Drekar Trooper',
#  'Drover Bursa',
#  'Dru Pesfor (1.25%)',
#  'Eidolon Vomvalyst (0.30%)',
#  'Elite Sanctuary Onslaught',
#  'Emergency ExitTactical Alert reward',
#  'Equinox Mega Pack',
#  'Ergo Glast duringOperation: Ambulas Reborn',
#  'Excavation',
#  'Excavation (Rotation C)',
#  'Excavation Reward',
#  'Executioner Dhurnam',
#  'Feral Kavat',
#  'Feyarch Specter',
#  'Fomorian Sabotage',
#  'Fomorian Sabotage (5%)',
#  'Forgotten (Rare) Crates',
#  'General Sargas Ruk',
#  'Ghoul bounty',
#  'Grineer Archwing Interception Reward (Rotation A)',
#  'Grineer Capture Reward',
#  'Grineer Dargyn',
#  'Grineer DrekarScorpion',
#  'Grineer Nox',
#  'Grineer Ogma',
#  'Grineer Sealab Sabotage Resource Caches',
#  'Grineer Shield-Hellion Dargyn',
#  'Grineer T1 LaresDefense Reward',
#  'Grineer T3Defense Reward',
#  'Grineer Warden',
#  'Grineer Warden (0.03%)',
#  'GrineerArid Butcher',
#  'GrineerArid Butcher (0.03%)',
#  'GrineerArid Eviscerator',
#  'GrineerArid Heavy Gunner',
#  'GrineerArid Heavy Gunner (0.03%)',
#  'GrineerArid Hellion',
#  'GrineerArid Hellion (0.015%)',
#  'GrineerArid Lancer',
#  'GrineerArid Lancer (0.015%)',
#  'GrineerArid Seeker',
#  'GrineerArid Trooper',
#  'GrineerArtificer',
#  'GrineerBailiff',
#  'GrineerBailiff Defector',
#  'GrineerBallista',
#  'GrineerBombard',
#  'GrineerButcher',
#  'GrineerCarabus',
#  'GrineerCommander',
#  'GrineerDarek Draga',
#  'GrineerDargyn',
#  'GrineerDesert Heavy Gunner',
#  'GrineerDraga',
#  'GrineerDrahk Master',
#  'GrineerDreg',
#  'GrineerDrekar Ballista',
#  'GrineerDrekar Butcher',
#  'GrineerDrekar Elite Lancer',
#  'GrineerDrekar Eviscerator',
#  'GrineerDrekar Heavy Gunner',
#  'GrineerDrekar Hellion',
#  'GrineerDrekar Lancer',
#  'GrineerDrekar Manic',
#  'GrineerDrekar Manic Bombard',
#  'GrineerDrekar Scorpion',
#  'GrineerDrekar Scorpion (0.015%)',
#  'GrineerDrekar Seeker',
#  'GrineerDrekar Trooper',
#  'GrineerElite Arid Lancer',
#  'GrineerElite Frontier Lancer',
#  'GrineerElite Lancer',
#  'GrineerEviscerator',
#  'GrineerFlameblade',
#  'GrineerFrontier Butcher',
#  'GrineerFrontier Butcher (0.03%)',
#  'GrineerFrontier Eviscerator',
#  'GrineerFrontier Heavy Gunner',
#  'GrineerFrontier Heavy Gunner (0.015%)',
#  'GrineerFrontier Hellion',
#  'GrineerFrontier Hellion (0.015%)',
#  'GrineerFrontier Hellion GrineerFrontier Lancer',
#  'GrineerFrontier Lancer',
#  'GrineerFrontier Lancer (0.015%)',
#  'GrineerFrontier Regulator',
#  'GrineerFrontier Seeker',
#  'GrineerFrontier Trooper',
#  'GrineerGuardsman',
#  'GrineerGuardsman Eximus',
#  'GrineerHeavy Gunner',
#  'GrineerHeavy Gunner (0.03%)',
#  'GrineerHellion',
#  'GrineerHellion (0.015%)',
#  'GrineerHellion Dargyn',
#  'GrineerHellion Power Carrier',
#  'GrineerHyekka Master',
#  'GrineerLancer',
#  'GrineerLancer (0.015%)',
#  'GrineerLancer Dreg',
#  'GrineerManic',
#  'GrineerManic Bombard',
#  'GrineerNapalm',
#  'GrineerOgma',
#  'GrineerPower Carrier',
#  'GrineerPowerfist',
#  'GrineerRegulator',
#  'GrineerRoller',
#  'GrineerRoller Sentry',
#  'GrineerScorch',
#  'GrineerScorpion',
#  'GrineerSeeker',
#  'GrineerShield Dargyn',
#  'GrineerShield Lancer',
#  'GrineerShield-Hellion Dargyn',
#  'GrineerShock Draga',
#  'GrineerSikula',
#  'GrineerTemporal Dreg',
#  'GrineerTrooper',
#  'GrineerZeplen',
#  'GrinnerGuardsman Eximus',
#  'Guardsman',
#  'Guardsman Eximus',
#  'Hemocyte',
#  'Hive Sabotage Cache',
#  'Hive Sabotage Cache Reward',
#  'Hive Sabotage cache reward',
#  'Hyekka',
#  'Hyena Pack',
#  'Incursions',
#  'Incursions 0.29% (Rot C)',
#  'Incursions 1.01% (Rot A)',
#  'Incursions 1.01% (Rot B)',
#  'Infested Chroma',
#  'Infested Chroma (0.6%)',
#  'Infested Mesa',
#  'Infested Mesa (0.6%)',
#  'Infested T3Defense Reward',
#  'InfestedAncient Disrupter',
#  'InfestedAncient Disruptor',
#  'InfestedAncient Healer',
#  'InfestedArcane Boiler',
#  'InfestedAttack Mutalist',
#  'InfestedBoiler',
#  'InfestedBrood Mother',
#  'InfestedCharger',
#  'InfestedCrawler',
#  'InfestedElectric Crawler',
#  'InfestedJordas Golem',
#  'InfestedJuggernaut',
#  'InfestedJuggernaut Behemoth',
#  'InfestedLeaper',
#  'InfestedLobber Crawler',
#  'InfestedMutalist Lightning Carrier',
#  'InfestedMutalist Osprey',
#  'InfestedMutalist Osprey Carrier',
#  'InfestedMutalist Toxic Carrier',
#  'InfestedNauseous Crawler',
#  'InfestedSwarm-Mutalist MOA',
#  'InfestedTar-Mutalist MOA',
#  'InfestedToxic Ancient',
#  'InfestedToxic Crawler',
#  'InfestedVolatile Runner',
#  'Informant Event',
#  'Interception',
#  'Interception Reward',
#  'Interception Reward at Rhea,Saturn',
#  'Interception Wave Reward',
#  'Invasions',
#  'Isolator Bursa (2.01%)',
#  'J3-Golem',
#  'Jackal',
#  'Jad Teran',
#  'Jad Teran (1.25%)',
#  'Jen Dro',
#  'Jen Dro (1.25%)',
#  'Jordas Golem',
#  'Kela De Thaym',
#  'KeplerPhobos Rush Reward',
#  'KeplerPhobos Rush RewardErpo Earth Sabotage Reward',
#  'Knave Specter',
#  'Kubrow (Feral)',
#  'Landing Craft',
#  'Lephantis',
#  'Lephantis (Phase 1 )',
#  'Lieutenant Lech Kril',
#  'Lith A1 Common',
#  'Lith A1 Rare',
#  'Lith A1 Uncommon',
#  'Lith B2 Rare',
#  'Lith B3 Common',
#  'Lith B5 Uncommon',
#  'Lith B6 Uncommon',
#  'Lith C1 Common',
#  'Lith C1 Rare',
#  'Lith C1 Uncommon',
#  'Lith C2 Uncommon',
#  'Lith C3 Rare',
#  'Lith F1 Common',
#  'Lith F1 Rare',
#  'Lith F1 Uncommon',
#  'Lith F2 Common',
#  'Lith F2 Rare',
#  'Lith F2 Uncommon',
#  'Lith H1 Rare',
#  'Lith H1 Uncommon',
#  'Lith H2 Common',
#  'Lith K1 Common',
#  'Lith K1 Rare',
#  'Lith K1 Uncommon',
#  'Lith M1 Common',
#  'Lith M1 Rare',
#  'Lith M1 Uncommon',
#  'Lith M3 Rare',
#  'Lith M4 Uncommon (11%)',
#  'Lith M4 Uncommon (25.3%)',
#  'Lith N1 Common',
#  'Lith N1 Rare',
#  'Lith N1 Uncommon',
#  'Lith N2 Rare',
#  'Lith N2 Uncommon',
#  'Lith N3 Common',
#  'Lith N3 Rare',
#  'Lith O1 Common',
#  'Lith P1 Rare',
#  'Lith P2 Uncommon (25.3%)',
#  'Lith S1 Common',
#  'Lith S1 Rare',
#  'Lith S1 Uncommon',
#  'Lith S2 Common',
#  'Lith S2 Rare',
#  'Lith S2 Uncommon',
#  'Lith S3 Common',
#  'Lith S3 Rare',
#  'Lith S3 Uncommon',
#  'Lith S7 Common',
#  'Lith S7 Uncommon',
#  'Lith V1 Common',
#  'Lith V1 Rare',
#  'Lith V1 Uncommon',
#  'Lith V3 Uncommon',
#  'Lith V4 Common',
#  'Lith V4 Uncommon',
#  'Lith Z1 Rare',
#  'Lockjaw & Sol',
#  'Lockjaw & Sol (1.25%)',
#  'Lynx',
#  'Lynx Osprey',
#  'Lynx Turret',
#  'M-W.A.M. (1.25%)',
#  'M-WAM',
#  'Malice',
#  'MaliceMisery',
#  'Mania',
#  'Mars',
#  'Meso A1 Rare',
#  'Meso B1 Common',
#  'Meso B1 Rare',
#  'Meso B1 Uncommon',
#  'Meso B2 Uncommon',
#  'Meso C1 Common',
#  'Meso C1 Rare',
#  'Meso C1 Uncommon',
#  'Meso C2 Common',
#  'Meso C2 Uncommon',
#  'Meso C3 Common',
#  'Meso C3 Uncommon',
#  'Meso D1 Common',
#  'Meso D1 Rare',
#  'Meso D1 Uncommon',
#  'Meso D2 Rare',
#  'Meso E2 Rare (2%)',
#  'Meso F1 Common',
#  'Meso F1 Rare',
#  'Meso F1 Uncommon',
#  'Meso G1 Uncommon',
#  'Meso H1 Common',
#  'Meso K1 Common',
#  'Meso K1 Rare',
#  'Meso M2 Uncommon',
#  'Meso M3 Uncommon (11%)',
#  'Meso N1 Common',
#  'Meso N1 Rare',
#  'Meso N1 Uncommon',
#  'Meso N2 Common',
#  'Meso N2 Rare',
#  'Meso N2 Uncommon',
#  'Meso N3 Rare',
#  'Meso N3 Uncommon',
#  'Meso N4 Rare',
#  'Meso N4 Uncommon',
#  'Meso N5 Rare',
#  'Meso N5 Uncommon',
#  'Meso O1 Rare',
#  'Meso O2 Common',
#  'Meso R1 Rare',
#  'Meso S1 Common',
#  'Meso S1 Rare',
#  'Meso S1 Uncommon',
#  'Meso S2 Common',
#  'Meso S2 Rare',
#  'Meso S2 Uncommon',
#  'Meso S3 Common',
#  'Meso S4 Common',
#  'Meso S5 Rare',
#  'Meso S6 Common',
#  'Meso S8 Common',
#  'Meso T1 Rare',
#  'Meso T2 Rare',
#  'Meso T3 Uncommon',
#  'Meso V1 Common',
#  'Meso V1 Rare',
#  'Meso V1 Uncommon',
#  'Meso V2 Common',
#  'Meso V2 Rare',
#  'Meso V2 Uncommon',
#  'Meso V3 Rare',
#  'Meso V3 Uncommon',
#  'Meso V5 Uncommon',
#  'Meso Z1 Uncommon',
#  'Meso Z2 Common',
#  'Meso Z3 Uncommon (25.3%)',
#  'Mine Osprey',
#  'Mirage Bundle',
#  'Misery',
#  'Montes,Venus',
#  'Mutalist Alad V',
#  'Mutalist Osprey',
#  'N/A',
#  'Nako Xol',
#  'Nako Xol (1.25%)',
#  'Neo A1 Uncommon',
#  'Neo B1 Rare',
#  'Neo B2 Rare',
#  'Neo B4 Common',
#  'Neo B4 Uncommon',
#  'Neo B5 Uncommon',
#  'Neo D1 Common',
#  'Neo D1 Rare',
#  'Neo D1 Uncommon',
#  'Neo G1 Rare',
#  'Neo H1 Rare',
#  'Neo H1 Uncommon',
#  'Neo H2 Uncommon',
#  'Neo K1 Uncommon',
#  'Neo K2 Common',
#  'Neo L1 Rare',
#  'Neo M1 Common',
#  'Neo M1 Rare',
#  'Neo M2 Rare',
#  'Neo N1 Common',
#  'Neo N1 Rare',
#  'Neo N1 Uncommon',
#  'Neo N10 Uncommon (11%)',
#  'Neo N2 Common',
#  'Neo N2 Rare',
#  'Neo N2 Uncommon',
#  'Neo N3 Common',
#  'Neo N3 Rare',
#  'Neo N3 Uncommon',
#  'Neo N4 Rare',
#  'Neo N4 Uncommon',
#  'Neo N5 Common',
#  'Neo N5 Rare',
#  'Neo N6 Rare',
#  'Neo N6 Uncommon',
#  'Neo N7 Common',
#  'Neo N7 Rare ',
#  'Neo N7 Uncommon',
#  'Neo N8 Common',
#  'Neo O1 Common',
#  'Neo O1 Uncommon',
#  'Neo S1 Common',
#  'Neo S1 Rare',
#  'Neo S1 Uncommon',
#  'Neo S11 Rare (2%)',
#  'Neo S2 Common',
#  'Neo S2 Rare',
#  'Neo S2 Uncommon',
#  'Neo S3 Common',
#  'Neo S3 Rare',
#  'Neo S3 Uncommon',
#  'Neo S6 Rare',
#  'Neo S7 Common',
#  'Neo S7 Rare',
#  'Neo S7 Uncommon',
#  'Neo S8 Common',
#  'Neo S8 Uncommon',
#  'Neo S9 Common',
#  'Neo T1 Uncommon',
#  'Neo V1 Common',
#  'Neo V1 Rare',
#  'Neo V1 Uncommon',
#  'Neo V2 Common',
#  'Neo V2 Rare',
#  'Neo V2 Uncommon',
#  'Neo V3 Common',
#  'Neo V3 Rare',
#  'Neo V3 Uncommon',
#  'Neo V4 Common',
#  'Neo V4 Rare',
#  'Neo V5 Common',
#  'Neo V6 Uncommon',
#  'Neo V7 Common',
#  'Neo Z1 Common',
#  'Neo Z1 Rare',
#  'Neo Z2 Uncommon',
#  'New Loka',
#  'New Loka Offering',
#  'Nightmare Mode Reward',
#  'Nightmare Mode reward',
#  'Nightmare Mode reward,Alert',
#  'Nightmare Mode rewardAlerts',
#  'NightmareAlert Reward',
#  'Nightwave',
#  'None',
#  'Offering',
#  'Old Man Suumbaat',
#  'Old Man Suumbaat’s Offerings',
#  'Once Awake Quest reward',
#  'One Thousand Cuts Reward',
#  'Operation Arid Fear',
#  'Operation Eyes of Blight Reward',
#  'Operation False Profit reward',
#  'Operation Oxium Espionage',
#  'Operation Sling-Stone',
#  'Operation: Ambulas Reborn',
#  'Operation: Gate Crash reward',
#  'Operation: Mutalist Incursions Reward',
#  'Operation: Mutalist Incursions reward',
#  'Operation: Plague Star',
#  'Operation: Rathuum Tier 1',
#  'Orokin Container',
#  'Orokin Drone',
#  'Orokin Moon Spy Reward',
#  'Orokin Moon Spy reward',
#  'Orokin Moon Test',
#  'Orokin Sabotage',
#  'Orokin Spectator',
#  'Orokin Storage Containers',
#  'Orokin Vault',
#  'Orokin Void Container',
#  'Orokin Void Containers',
#  'Orokin Void containers',
#  'OrokinStorage Container',
#  'Orphid Specter',
#  "Overtake RewardDenial BursaBaro Ki'TeerOrokin Moon Spy RewardRathuum - Mission 3 (0.5%)",
#  'Pelna Cade',
#  'Pelna Cade (1.25%)',
#  'Perrin Sequence',
#  'Phoenix Intercept Reward',
#  'Phorid',
#  'Plains Commander (0.02%)',
#  'Plains Commander (0.33%)',
#  'Plains Commander (1.14%)',
#  'Prod Crewman',
#  'Project Undermine Reward',
#  'Rana Del (1.25%)',
#  'Raptor',
#  'Raptor RX',
#  'Raptor RX (1.25%)',
#  'Rathuum - Mission 3 (0.25%)',
#  'Rathuum - Mission 3 (0.50%)',
#  'Rathuum Arenas',
#  'Razorback',
#  'Recon Commander (0.02%)',
#  'Recon Commander (0.33%)',
#  'Recon Commander (1.14%)',
#  'Red Veil',
#  'Red Veil Offering',
#  'Referral Program',
#  'Reward fromOperation Breeding Grounds',
#  'Reward fromOperation Cryotic Front',
#  'Reward fromThe Cicero Crisis',
#  'Roller',
#  'Sabotage ,Uranus',
#  'Sanctuary Onslaught',
#  'ScorpionHuntress Bundle',
#  'Sealab Sabotage Resource Cache',
#  'Shadow Stalker',
#  'Shadow Stalker (30.56%)',
#  'Shield Osprey',
#  'Shield-Hellion DargynPhobos Rush Reward',
#  'Shockwave MOA',
#  'Sikula',
#  'Simaris Offerings',
#  'Smokefinger’s Offerings in Fortuna',
#  'Sorties',
#  'Sprag',
#  'Spy 2.0',
#  'Spy 2.0 Reward',
#  'Spy 2.0 reward',
#  'Spy Reward',
#  'Stalker',
#  'Stalker (30.56%)',
#  'Steel Meridian',
#  'Steel Meridian Offering',
#  'Steel MeridianArbiters of Hexis',
#  'Survival (Rotation C)',
#  'Survival Tier 1 Rotation C',
#  'Survival Weekend Event',
#  'Swarm-Mutalist MOA',
#  'Syrtis,Mars',
#  'Tactical Alert (Divine Will )',
#  'Tactical Alert (Divine Will ) Endurance Reward',
#  'Tactical Alert Emergency Exit',
#  'Tar-Mutalist MOA',
#  "Tethra's Doom Reward",
#  'The Cicero Crisis',
#  'The Grustrag Three',
#  'The Index',
#  'The Perrin Sequence',
#  'The Perrin Sequence Offering',
#  'The Quills',
#  'The Sergeant',
#  'The War Within quest',
#  'Tia Mayn',
#  'Tia Mayn (1.25%)',
#  'Tier 1/2/3Survival Reward',
#  'Tier 1Defense',
#  'Tier 1Excavation Rotation C',
#  'Tier 1Excavation reward',
#  'Tier 1Survival Reward',
#  'Tier 1Survival Rotation C',
#  'Tier 2 InfestedDefense Reward',
#  'Tier 2-3Survival Reward',
#  'Tier 2Arena Reward',
#  'Tier 2Defense Reward',
#  'Tier 2Survival Reward',
#  'Tier 3Defense Reward',
#  'Tier 3Excavation Reward',
#  'Tier 3Spy vault reward',
#  'Tier 3Survival',
#  'Tier 3Survival Reward',
#  'Tier 4-6Platinum Packs',
#  'Tier 5-6Platinum Packs',
#  'Tier 6Platinum Packs',
#  'Torment',
#  'Toxic Ancient',
#  'Tyl Regor',
#  'Ved Xol',
#  'Ved Xol (1.25%)',
#  "Ven'kra Tel",
#  'Ventkids',
#  'Violence',
#  "Vor's Prize (Damaged )",
#  "Vor's Prize (Damaged)",
#  'Yam, Sedna (0.25%)'}

# %% [markdown]
# #### Create tags and drops table (and the bridge tables)

# %%
# Create 'tags' table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS tags (
    tag_id INT AUTO_INCREMENT PRIMARY KEY,
    tag_name VARCHAR(255))
    """)
    conn.commit()
except:
    conn.rollback()
    
# Populate table 'tags' with all tags
try:
    x.executemany(
    """
    INSERT INTO tags (tag_name)
    VALUES (%s)
    """, list(all_tags))
    conn.commit()
except:
    conn.rollback()
    
# Create 'items_tags' bridge table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS items_tags (
    item_id VARCHAR(255),
    FOREIGN KEY (item_id) REFERENCES items(item_id),
    tag_id INT,
    FOREIGN KEY (tag_id) REFERENCES tags(tag_id))
    """)
    conn.commit()
except:
    conn.rollback()

# %%
# Create 'drops' table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS drops (
    drop_id INT AUTO_INCREMENT PRIMARY KEY,
    drop_name VARCHAR(255))
    """)
    conn.commit()
except:
    conn.rollback()

# Populate table 'drops' with all drops
# Unicode "\u2019" is annoying
try:
    for drop in list(all_drops):
        x.execute(
        """
        INSERT INTO drops (drop_name)
        VALUES (%s)
        """, [drop.replace("\u2019", "'")])
        conn.commit()
except:
    conn.rollback()
    
# Create 'items_drops' bridge table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS items_drops (
    item_id VARCHAR(255),
    FOREIGN KEY (item_id) REFERENCES items(item_id),
    drop_id INT,
    FOREIGN KEY (drop_id) REFERENCES drops(drop_id))
    """)
    conn.commit()
except:
    conn.rollback()

# %% [markdown]
# #### Item sets
# We see that items are grouped by their item sets. Thus, we want to have a separate table containing all item sets in the game.

# %%
# Using set because we want only unique elements
all_sets = set([])

############################################################################
# HEY YO, THIS TAKES LIKE 25 MINUTES TO RUN SO DON'T USE IT MORE THAN ONCE #
############################################################################

# Get all dictionary keys from JSON for all items
for item in items["payload"]["items"]["en"]:
    # Url switch-a-roo that goes through all item urls
    url_name = item["url_name"]
    req = s.get("https://api.warframe.market/v1/items/" + url_name).json()
    # Grabs sets from each item page if it is part of a set (i.e. more than one item is returned)
    if (len(req["payload"]["item"]["items_in_set"]) > 1):
        for item_in_set in req["payload"]["item"]["items_in_set"]:
            if item_in_set["set_root"]:
                all_sets.add(item_in_set["en"]["item_name"])
    
    # I use 2 requests per second max
    time.sleep(0.5)

all_sets
# Out:
# {'Agkuza Set',
#  'Akbolto Prime Set',
#  'Akbronco Prime Set',
#  'Akjagara Prime Set',
#  'Aklex Prime Set',
#  'Akstiletto Prime Set',
#  'Akvasto Prime Set',
#  'Amesha Set',
#  'Ankyros Prime Set',
#  'Ash Prime Set',
#  'Ballistica Prime Set',
#  'Banshee Prime Set',
#  'Bo Prime Set',
#  'Boar Prime Set',
#  'Boltor Prime Set',
#  'Braton Prime Set',
#  'Braton Vandal Set',
#  'Broken War Set',
#  'Bronco Prime Set',
#  'Burston Prime Set',
#  'Carrier Prime Set',
#  'Centaur Set',
#  'Cernos Prime Set',
#  'Chroma Prime Set',
#  'Corvas Set',
#  'Cyngas Set',
#  'Dakra Prime Set',
#  'Dera Vandal Set',
#  'Destreza Prime Set',
#  'Dual Decurion Set',
#  'Dual Kamas Prime Set',
#  'Elytron Set',
#  'Ember Prime Set',
#  'Equinox Prime Set',
#  'Euphona Prime Set',
#  'Fang Prime Set',
#  'Fluctus Set',
#  'Fragor Prime Set',
#  'Frost Prime Set',
#  'Furax Wraith Set',
#  'Galatine Prime Set',
#  'Glaive Prime Set',
#  'Gorgon Wraith Set',
#  'Gram Prime Set',
#  'Helios Prime Set',
#  'Hikou Prime Set',
#  'Hydroid Prime Set',
#  'Imperator Vandal Set',
#  'Itzal Set',
#  'Karak Wraith Set',
#  'Kaszas Set',
#  'Kavasa Prime Collar Set',
#  'Kogake Prime Set',
#  'Kronen Prime Set',
#  'Lato Vandal Set',
#  'Latron Prime Set',
#  'Latron Wraith Set',
#  'Lex Prime Set',
#  'Limbo Prime Set',
#  'Loki Prime Set',
#  'Mag Prime Set',
#  'Mantis Set',
#  'Mesa Prime Set',
#  'Mirage Prime Set',
#  'Nami Skyla Prime Set',
#  'Nekros Prime Set',
#  'Nikana Prime Set',
#  'Nova Prime Set',
#  'Nyx Prime Set',
#  'Oberon Prime Set',
#  'Odonata Prime Set',
#  'Onorix Set',
#  'Orthos Prime Set',
#  'Paris Prime Set',
#  'Phaedra Set',
#  'Pyrana Prime Set',
#  'Rathbone Set',
#  'Reaper Prime Set',
#  'Redeemer Prime Set',
#  'Rhino Prime Set',
#  'Rubico Prime Set',
#  'Saryn Prime Set',
#  'Scimitar Set',
#  'Scindo Prime Set',
#  'Sheev Set',
#  'Sicarus Prime Set',
#  'Silva & Aegis Prime Set',
#  'Snipetron Vandal Set',
#  'Soma Prime Set',
#  'Spira Prime Set',
#  'Stradavar Prime Set',
#  'Strun Wraith Set',
#  'Sybaris Prime Set',
#  'Tiberon Prime Set',
#  'Tigris Prime Set',
#  'Tipedo Prime Set',
#  'Trinity Prime Set',
#  'Twin Vipers Wraith Set',
#  'Valkyr Prime Set',
#  'Vasto Prime Set',
#  'Vauban Prime Set',
#  'Vectis Prime Set',
#  'Velocitus Set',
#  'Venka Prime Set',
#  'Volt Prime Set',
#  'Wolf Sledge Set',
#  'Wyrm Prime Set',
#  'Xiphos Set',
#  'Zephyr Prime Set'}

# %%
# Create 'sets' table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS sets (
    set_id INT AUTO_INCREMENT PRIMARY KEY,
    set_name VARCHAR(255))
    """)
    conn.commit()
except:
    conn.rollback()
    
# Populate table 'sets' with all sets
try:
    x.executemany(
    """
    INSERT INTO sets (set_name)
    VALUES (%s)
    """, list(all_sets))
    conn.commit()
except:
    conn.rollback()

# %% [markdown]
# #### Item info
# Just a big scraper.

# %%
# Using time.sleep to not flood API requests. Recommend 3 requests per second
import time


# Smart scraper: if an item is a sibling to the requested item then it is already scraped and we skip it
scraped_items = set([])

# HTML tag cleaner
import re
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# Create 'item_info' table
try:
    x.execute(
    """
    CREATE TABLE IF NOT EXISTS item_info (
    item_id VARCHAR(255) PRIMARY KEY,
    FOREIGN KEY (item_id) REFERENCES items(item_id),
    item_name VARCHAR(255),
    item_description VARCHAR(1000) DEFAULT NULL,
    item_wiki VARCHAR(255) DEFAULT NULL,
    rarity VARCHAR(255) DEFAULT NULL,
    mastery_level INT DEFAULT NULL,
    trading_tax INT DEFAULT NULL,
    mod_max_rank INT DEFAULT NULL,
    ducats INT DEFAULT NULL,
    set_id INT DEFAULT NULL,
    FOREIGN KEY (set_id) REFERENCES sets(set_id))
    """)
    conn.commit()
except:
    conn.rollback()

for item in items["payload"]["items"]["en"]:
    # Navigate to item information page
    url_name = item["url_name"]
    req = s.get("https://api.warframe.market/v1/items/" + url_name).json()
    
    # If there is more than one item returned, then it is part of a set and we want to find which one
    set_id = None
    if len(req["payload"]["item"]["items_in_set"]) > 1:
        for item_in_set in req["payload"]["item"]["items_in_set"]:
            if (item_in_set["set_root"]):
                item_set = item_in_set["en"]["item_name"]
                set_id = int(pd.read_sql_query("""
                SELECT set_id
                FROM sets
                WHERE set_name LIKE %s
                """, conn, params = [item_set]).values)
    
    # Get all item information
    for item_in_set in req["payload"]["item"]["items_in_set"]:
        # Item ID
        item_id = item_in_set["id"]
        
        if item_id not in scraped_items:
            # Item name
            item_name = item_in_set["en"]["item_name"]

            # Description
            item_description = cleanhtml(item_in_set["en"]["description"])

            # Wiki link
            if "wiki_link" in item_in_set["en"]:
                item_wiki = item_in_set["en"]["wiki_link"]
            else:
                item_wiki = None

            # Drops (if applicable)
            # This populates our bridge table 'items_drops'
            if "drop" in item_in_set["en"]:
                for drop in item_in_set["en"]["drop"]:
                    # Get drop_id from drop_name
                    drop_id = pd.read_sql_query("""
                    SELECT drop_id
                    FROM drops
                    WHERE drop_name LIKE %s
                    """, conn, params = [drop["name"].replace("\u2019", "'")])

                    # Add to 'items_drops'
                    try:
                        x.execute(
                        """
                        INSERT INTO items_drops (item_id, drop_id)
                        VALUES (%s, %s)
                        """, [item_id, int(drop_id.values)])
                        conn.commit()
                    except:
                        conn.rollback()

            # Tags
            # This populates our bridge table 'items_tags'
            for tag in item_in_set["tags"]:
                # Get tag_id from tag_name
                tag_id = pd.read_sql_query("""
                SELECT tag_id
                FROM tags
                WHERE tag_name LIKE %s
                """, conn, params = [tag])

                # Add to 'items_tags'
                try:
                    x.execute(
                    """
                    INSERT INTO items_tags (item_id, tag_id)
                    VALUES (%s, %s)
                    """, [item_id, int(tag_id.values)])
                    conn.commit()
                except:
                    conn.rollback()

            # Ducats (if applicable)
            if "ducats" in item_in_set:
                ducats = int(item_in_set["ducats"])
            else:
                ducats = None

            # Mastery level (if applicable)
            if "mastery_level" in item_in_set:
                mastery_level = int(item_in_set["mastery_level"])
            else:
                mastery_level = None

            # Trading tax (if applicable)
            if "trading_tax" in item_in_set:
                trading_tax = item_in_set["trading_tax"]
            else:
                trading_tax = None

            # Max mod rank (if applicable)
            if "mod_max_rank" in item_in_set:
                mod_max_rank = item_in_set["mod_max_rank"]
            else:
                mod_max_rank = None

            # Rarity (if applicable)
            if "rarity" in item_in_set:
                rarity = item_in_set["rarity"]
            else:
                rarity = None

            # Insert into item_info table
            try:
                x.execute(
                """
                INSERT INTO item_info (item_id, item_name, item_description, item_wiki, rarity, mastery_level, trading_tax, mod_max_rank, ducats, set_id)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """, [item_id, item_name, item_description, item_wiki, rarity, mastery_level, trading_tax, mod_max_rank, ducats, set_id])
                conn.commit()
            except:
                conn.rollback()

            # Smart scraper function
            scraped_items.add(item_id)
  
    # 2 requests per second
    time.sleep(0.5)

# %%
# Save workspace
del conn
del x

import dill
#dill.dump_session('market.db') # Save
#dill.load_session('market.db') # Load

### https://github.com/WFCD - Warframe community developers
